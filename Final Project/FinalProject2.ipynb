# %%
#Intro and Story
import random
from IPython.display import display, HTML  

quest1 = "incomplete"
#player stats
player_class = "none"
wallet=0
pocket=[]
stat_str=0
mod_str=0
stat_dex=0
mod_dex=0
stat_con=0
mod_con=0
stat_cha=0
mod_cha=0
stat_int=0
mod_int=0
stat_wis=0
mod_wis=0
player_hp="none"
player_lvl=2
#player_xp=300
weapon1="blank"
weapon2="blank"
weapon3="blank"
weapon4="blank"
ammo1=10
player_num=2
goyle_num=1
mant_num=1
bandit_num = 1
player_ac="none"
spell1="none"
spell2="none"
player_spells=[spell1, spell2]
spell_slot=0
spell_list = ['cloud of daggers','witch bolt','ray of sickness','scorching ray']
resistancy= "None"
player_resistancies = [resistancy]
#goyle stats
goyle_ac=11
goyle_hp=31
goyle_sp=30
goyle_fl=60
goyle_str=15
goyle_mod_str=2
goyle_dex=11
goyle_mod_dex=0
goyle_con=16
goyle_mod_con=3
goyle_int=6
goyle_mod_int=-2
goyle_wis=11
goyle_mod_wis=0
goyle_cha=7
goyle_mod_cha=-2
goyle_resistancies=["slashing"]
#mant stats
mant_ac = 14
mant_hp = 30
mant_str = 17
mant_mod_str = 3
mant_dex= 16
mant_mod_dex = 3
mant_con = 17
mant_mod_con = 3
mant_int = 7
mant_mod_int = -2
mant_wis = 12
mant_mod_wis = 1
mant_cha = 8
mant_mod_cha = -1
mant_resistancies = "none"
#bandit stats
bandit_ac = 11
bandit1_hp = 11
bandit2_hp = 11
bandit_str = 11
bandit_mod_str = 0
bandit_dex= 12
bandit_mod_dex = 1
bandit_con = 12
bandit_mod_con = 1
bandit_int = 10
bandit_mod_int = 0
bandit_wis = 10
bandit_mod_wis = 0
bandit_cha = 10
bandit_mod_cha = 0
bandit_num=2
bandit_num=1
bandit1_attack=0
bandit2_attack=0

all_weapons=["longsword","shortsword","morningstar","sling","quarterstaff","dagger","light crossbow","hand crossbow"]

def Startup():
    start = input("Yes or no?\n")
    if start == "yes":
        Intro()
        QuestChoice()

    elif start == "no":
        print("Perhaps ye are not ready yet. Come back when ye are!")

    else:
        print("I didn't understand ye there, sonny.\n")
        Startup()


def YouDied():
    print(("-"*25)+"Defeat"+("-"*25))
    print("Ye fall to the ground, yer armor torn to shreds and yer weapons broken.\n")
    display(HTML("<H2>YE DIED!<H2>"))
    print("Better luck next time!")

def Fweapon1():
    global weapon1
    weapon1=input("Now, as a fighter, yer goin' to need some weapons! I'll give ye the choice between a Longsword and a Morningstar.\n").lower()
    if weapon1 == "longsword" or weapon1 == "morningstar":
        print("Good choice, me friend!")
    else:
        print("I gave ye a choice!")
        Fweapon1()
                
def Fweapon2():
    global weapon2
    weapon2=input("Now for ranged weapons! I'll give ye the choice between a Hand Crossbow and a Sling.\n").lower()
    if weapon2=="sling" or weapon2=="hand crossbow":
        print("Good choice, me friend!")
    else:
        print("I gave ye a choice!")
        Fweapon2()
        
def Farmor():
    global mod_dex
    global player_ac
    player_ac=input("Now fer yer armor. Ye can choose chain mail or breastplate.\n").lower()
    if player_ac=="chain mail" or player_ac=="chanimail":
        player_ac=14
        print("Good pick!")
    elif player_ac=="breast plate" or player_ac=="breastplate":
        player_ac=13
        print("Good Pick!")
    else:
        print("I gave ye a choice!")
        Farmor()
        
def Wweapon1():
    global weapon1
    weapon1=input("Now, as a wizard, yer goin' to mainly use spells, but weapons are still important! I'll give ye the choice between a quarterstaff and a dagger.\n").lower()
    if weapon1 == "quarterstaff" or weapon1 == "dagger":
        print("Good choice, me friend!")
    else:
        print("I gave ye a choice!")
        Wweapon1()
 
def Wweapon2():
    global weapon2
    weapon2=input("Now for ranged weapons! I'll give ye the choice between a sling and a light crossbow.\n").lower()
    if weapon2 == "sling" or weapon2 == "light crossbow":
        print("Good choice, me friend!")
    else:
        print("I gave ye a choice!")
        Wweapon2()
        
def Warmor():
    global mod_dex
    global player_ac
    player_ac=input("Now fer yer armor. Ye can choose leather or studded.\n").lower()
    if player_ac=="leather":
        player_ac=11
        print("Good pick!")
    elif player_ac=="studded":
        player_ac=12
        print("Good Pick!")
    else:
        print("I gave ye a choice!")
        Warmor()

def Wspells():
    global spell1
    global spell2
    print("Now, as a wizard, ye'll need spells to cast! Choose 1 of the following spells:")
    spell_choices1=["ray of sickness","witch bolt"]
    spell1=input("Ye can have ray of sickness or witch bolt.\n").lower()
    if spell1 in spell_choices1:
        spell_choices2=["cloud of daggers", "scorching ray"]
        spell2=input("Good choice! Now ye can choose yer second spell to be either cloud of daggers or scorching ray.\n").lower()
        if spell2 in spell_choices2:
            print("That spell be a good one!")
        else:
            print("Ye have a choice, not entire free will!")
            Wspells()
    else:
        print("Ye have a choice, not entire free will!")
        Wspells()
        
def Rweapon1():
    global weapon1
    weapon1 = input("As a rogue, yer gonna want something small but equally powerful. I'll give ye the choice between a dagger or a shortsword.\n").lower()
    if weapon1 == "dagger" or weapon1 == "shortsword":
        print("Good choice!")
    else:
        print("I gave ye a choice!")
        Rweapon1()

def Rweapon2():
    global weapon2
    weapon2 = input("Now then, yer also gonna want a ranged weapon. I'll give ye the choice between a hand crossbow or a sling.\n").lower()
    if weapon2 == "sling" or weapon2 == "hand crossbow":
        print("Good choice!")
    else:
        print("I gave ye a choice!")
        Rweapon2()
        
def Rarmor():
    global mod_dex
    global player_ac
    player_ac=input("Now fer yer armor. Ye can choose leather or studded.\n").lower()
    if player_ac=="leather":
        player_ac=11
        print("Good pick!")
    elif player_ac=="studded":
        player_ac=12
        print("Good Pick!")
    else:
        print("I gave ye a choice!")
        Rarmor()
        
def PickClass():
    global player_ac
    global player_hp
    global weapon1
    global weapon2
    global stat_str
    global mod_str
    global stat_dex
    global mod_dex
    global stat_con
    global mod_con
    global stat_cha
    global mod_cha
    global stat_int
    global mod_int
    global stat_wis
    global mod_wis
    global player_class
    player_class = input("Pick a class: Fighter, Wizard, or Rogue\n").lower()
    #fighter
    if player_class == "fighter":
        print("Excellent choice! The Fighter is strong and uses primarily melee attacks, but are still good with ranged weapons.")
        stat_str=15
        mod_str=2
        stat_dex=14
        mod_dex=2
        stat_con=14
        mod_con=2
        stat_cha=13
        mod_cha=1
        stat_int=10
        mod_int=0
        stat_wis=11
        mod_wis=0
        Fweapon1()
        Fweapon2()
        Farmor()
        player_hp=23
        player_ac=player_ac+mod_dex
        print("Here are yer ability scores: %d for strength, %d for dexterity, %d for constitution, %d for charisma, %d for intelligence, and %d for wisdom!\n"%(stat_str, stat_dex, stat_con, stat_cha, stat_int, stat_wis))
        print("Here are yer weapons: %s and %s.\n"%(weapon1, weapon2))
        print("Yer armor class will be %d\n"%(player_ac))
        print("Ye'll start at level 2 for now!\n")
        
    #wizard
    elif player_class == "wizard":
        print("Excellent choice! The Wizard is a powerful class, utilizing primarily magic based attacks.")
        stat_str=10
        mod_str=0
        stat_dex=14
        mod_dex=2
        stat_con=14
        mod_con=2
        stat_cha=11
        mod_cha=0
        stat_int=15
        mod_int=2
        stat_wis=13
        mod_wis=1
        Wweapon1()
        Wweapon2()
        Warmor()
        Wspells()
        player_hp=24
        player_ac=player_ac+mod_dex
        player_lvl=3
        print("Here be yer ability scores: %d for strength, %d for dexterity, %d for constitution, %d for charisma, %d for intelligence, and %d for wisdom!\n"%(stat_str, stat_dex, stat_con, stat_cha, stat_int, stat_wis))
        print("Here be yer weapons: %s and %s.\n"%(weapon1, weapon2))
        print("Here be yer spells: %s and %s.\n"%(spell1, spell2))
        print("Yer armor class will be %d\n"%(player_ac))
        print("Ye'll start at level 3 for now!\n")
    
    #rogue
    elif player_class == "rogue":
        print("Excellent choice! The Rogue is a sneaky class. Rogues' attacks aren't very powerful, but they are very fast.")
        stat_str=13
        mod_str=1
        stat_dex=15
        mod_dex=2
        stat_con=14
        mod_con=2
        stat_cha=11
        mod_cha=0
        stat_int=14
        mod_int=2
        stat_wis=10
        mod_wis=0
        Rweapon1()
        Rweapon2()
        Rarmor()
        player_hp = 22
        player_ac = player_ac+mod_dex
        print("Here be yer ability scores: %d for strength, %d for dexterity, %d for constitution, %d for charisma, %d for intelligence, and %d for wisdom!\n"%(stat_str, stat_dex, stat_con, stat_cha, stat_int, stat_wis))
        print("Here be yer weapons: %s and %s.\n"%(weapon1, weapon2))
        print("Yer armor class will be %d\n"%(player_ac))
        print("Ye'll start at level 2 for now!\n")

    else:
        print("Oh my! I'm afraid that's not an option. Try again!") 
        PickClass()

def PickRace():
    global stat_str
    global stat_dex
    global stat_con
    global stat_cha
    global stat_int
    global stat_wis
    player_race = input("Now then...Pick a race: Human, Elf, or Dwarf\n").lower()
    if player_race == "human":
        print("Ah yes, the Human. Much like ye and I, they are intelligent life forms, able to do many things\n")
        #print("As a human, ye also gain one extra point to all of yer stats!\n")
        #stat_str=stat_str+1
        #stat_dex=stat_dex+1
        #stat_con=stat_con+1
        #stat_cha=stat_cha+1
        #stat_int=stat_int+1
        #stat_wis=stat_wis+1
        #print("Here be yer new ability scores: %d for strength, %d for dexterity, %d for constitution, %d for charisma, %d for intelligence, and %d for wisdom!\n"%(stat_str, stat_dex, stat_con, stat_cha, stat_int, stat_wis))
    elif player_race == "elf":
        print("Ah, the Elves. A highly intelligent race, the Elves are masters of ranged and magic combat.")
        #print("As an Elf, ye also gain two extra points to yer Dexterity stat!\n")
        #stat_dex=stat_dex+2
        #print("Here be yer new ability scores: %d for strength, %d for dexterity, %d for constitution, %d for charisma, %d for intelligence, and %d for wisdom!\n"%(stat_str, stat_dex, stat_con, stat_cha, stat_int, stat_wis))
    elif player_race == "dwarf":
        print("Hmm! The Dwarves were born from the earth and are skilled in weaponmaking. They are very strong, but lack agility")
        #print("As a Dwarf, ye also gain two extra points to yer Constitutuon stat!\n")
        #stat_con=stat_con+2
        #print("Here be yer new ability scores: %d for strength, %d for dexterity, %d for constitution, %d for charisma, %d for intelligence, and %d for wisdom!\n"%(stat_str, stat_dex, stat_con, stat_cha, stat_int, stat_wis))
        global resistancy1
        resistancy == "poison"
    else:
        print("Oh my! I'm afraid that's not an option. Try again!")
        PickRace()
        
def Intro():
    print("Excellent! Let's begin!")
    PickClass()
    PickRace()
    player_name = input("Now then! What is yer name?\n")
    print(player_name+"!","Are ye ready? Yer adventure awaits! Let's go!\n")
   
def QuestChoice():
    questnum = input("Now, choose the quest ye wish to embark on!\n --1:The Cave of Lightning\n --2:UNRELEASED\n")
    if questnum == "1":
        if quest1 == "incomplete":
            story1()
        elif quest1 == "complete":
            print("You've already completed that there quest!")
            QuestChoice()
    else:
        print("That quest isn't available yet! Try again!")
        QuestChoice()

def story1():
    print(("-"*25)+"Quest Start!"+("-"*25))
    print(" \n")
    print("After hearing rumors of treasure somewhere in the east, ye leave town in search of fortune.\n")
    print("As ye travel through the forest, ye feel the warm breeze through the trees, and ye admire the beauty of nature.\n")
    MiniFightBandit()
    
def MiniFightBandit():
    print(("-"*25)+"Bandit Fight"+("-"*25))
    print("Suddenly, two bandits come out from the bushes! They tell ye to forfeit all yer gold!")
    while True:
        if player_num>bandit_num or player_num==bandit_num:
            PlayerTurn_vs_Bandits()
            if bandit1_hp<1:
                MiniFight1Dead()
                break
            elif bandit2_hp<1:
                MiniFight2Dead()
                break
            BanditTurn()
            if player_hp<1:
                YouDied()
                break
                
def MiniFight1Dead():
    while True:
        if player_num>bandit_num or player_num==bandit_num:
            PlayerTurn_vs_Bandits()
            if bandit2_hp<1:
                PostBandit()
                break
            else:
                Scimitar2()
                if player_hp<1:
                    YouDied()
                    break

                
def MiniFight2Dead():
    while True:
        if player_num>bandit_num or player_num==bandit_num:
            PlayerTurn_vs_Bandits()
            if bandit1_hp<1:
                PostBandit()
                break
            else:
                Scimitar1()
                if player_hp<1:
                    YouDied()
                    break
                
def PlayerTurn_vs_Bandits():
    global weapon1
    global weapon2
    global spell1
    global spell2
    global player_spells
    global player_class
    global spell_list
    global bandit1_hp
    global bandit2_hp
    global player_hp
    global bandit_mod_con
    global spell_slot
    global ammo1
    global mod_int
    global mod_dex
    global mod_str
    if player_num>bandit_num or player_num==bandit_num:
        action = input("What will ye do now? (Attack, spell, run, talk, or quit)\n").lower()
        if action == "attack" or action == "fight" or action == "hit":
            atk_choice=input("Would ye like to attack the bandit in red or blue?\n").lower()
            if atk_choice=="red":
                if bandit1_hp<1:
                    print("That one's already dead!")
                    PlayerTurn_vs_Bandits()
                else:
                    weapon = input("What will ye attack with? (%s or %s)\n" % (weapon1,weapon2)).lower()

                    #longsword
                    if weapon == "longsword":
                        longsword_damtype="slashing"
                        if "longsword" == weapon1 or "longsword" == weapon2:
                            attack_roll = random.randint(5,20)+mod_str
                            if attack_roll>=bandit_ac:
                                bandit1_hp = bandit1_hp - random.randint(1,8)
                                print("Ye hit the Bandit in Red! He has %d HP left!" % (bandit1_hp))
                                if bandit1_hp<1:
                                    print("The Bandit in Red falls to the floor!")
                            elif attack_roll<bandit_ac:
                                print("Ye missed!") 
                        else:
                            print("Ye don't have a %s!" % (weapon))
                            PlayerTurn_vs_Bandits()

                    #shortsword
                    if weapon == "shortsword":
                        shortsword_damtype="piercing"
                        if "shortsword" == weapon1:
                            attack_roll = random.randint(5,20)+mod_str
                            if attack_roll>=bandit_ac:
                                bandit1_hp = bandit1_hp - random.randint(1,8)
                                print("Ye hit the Bandit in Red! He has %d HP left!" % (bandit1_hp))
                                if bandit1_hp<1:
                                    print("The Bandit in Red falls to the floor!")
                            elif attack_roll<bandit_ac:
                                print("Ye missed!")
                        else:
                            print("Ye don't have a %s!" % (weapon))
                            PlayerTurn_vs_Bandits()

                    #Morningstar
                    elif weapon == "morningstar":
                        morningstar_damtype="piercing"
                        if "morningstar" == weapon1:
                            attack_roll = random.randint(5,20)+mod_str
                            if attack_roll>=bandit_ac:
                                bandit1_hp = bandit1_hp - random.randint(1,8)
                                print("Ye hit the Bandit in Red! He has %d HP left!" % (bandit1_hp))
                                if bandit1_hp<1:
                                    print("The Bandit in Red falls to the floor!")
                            elif attack_roll<bandit_ac:
                                print("Ye missed!")
                        else:
                            print("Ye don't have a %s!" % (weapon))
                            PlayerTurn_vs_Bandits()

                    #Sling
                    if weapon == "sling":
                        sling_damtype="bludgeoning"
                        if "sling" == weapon2:
                            attack_roll = random.randint(5,20)+mod_dex
                            ammo1=ammo1-1
                            if ammo1>0:
                                if attack_roll>=bandit_ac:
                                    bandit1_hp = bandit1_hp - random.randint(1,4)
                                    print("Ye hit the Bandit in Red! It has %d HP left!" % (bandit1_hp))
                                    if bandit1_hp<1:
                                        print("The Bandit in Red falls to the floor!")
                                elif attack_roll<bandit_ac:
                                    print("Ye missed!")
                            elif ammo1<1:
                                print("Yer out of ammunition!")
                                PlayerTurn_vs_Bandits()
                        else:
                            print("Ye don't have a %s!" % (weapon))
                            PlayerTurn_vs_Bandits()

                    #Quarterstaff
                    elif weapon == "quarterstaff" or weapon == "quarter staff":
                        quarterstaff_damtype="bludgeoning"
                        if "quarterstaff" == weapon1:
                            attack_roll = random.randint(5,20)+mod_str
                            if attack_roll>=bandit_ac:
                                bandit1_hp = bandit1_hp - random.randint(1,6)
                                print("Ye hit the Bandit in Red! It has %d HP left!" % (bandit1_hp))
                                if bandit1_hp<1:
                                    print("The Bandit in Red falls to the floor!")
                            elif attack_roll<bandit_ac:
                                print("Ye missed!")
                        else:
                            print("Ye don't have a %s!"%(weapon))
                            PlayerTurn_vs_Bandits()

                    #Dagger
                    elif weapon == "dagger":
                        dagger_damtype="piercing"
                        if "dagger" == weapon1:
                            attack_roll = random.randint(5,20)+mod_str
                            if attack_roll>=bandit_ac:
                                    bandit1_hp = bandit1_hp - random.randint(1,6)
                                    print("Ye hit the Bandit in Red! It has %d HP left!" % (bandit1_hp))
                                    if bandit1_hp<1:
                                        print("The Bandit in Red falls to the floor!")
                            elif attack_roll<bandit_ac:
                                print("Ye missed!")
                        else:
                            print("Ye don't have that weapon!")
                            PlayerTurn_vs_Bandits()

                    #Light Crossbow
                    elif weapon == "light crossbow":
                        light_xbow_damtype="piercing"
                        if "light crossbow" == weapon2:
                            attack_roll = random.randint(5,20)+mod_dex
                            ammo1=ammo1-1
                            if ammo1>0:
                                if attack_roll>=bandit_ac:
                                    bandit1_hp = bandit1_hp - random.randint(1,6)
                                    print("Ye hit the Bandit in Red with yer crossbow! Good shot! It has %d HP left!" % (bandit1_hp))
                                    if bandit1_hp<1:
                                        print("The Bandit in Red falls to the floor!")
                                elif attack_roll<bandit_ac:
                                    print("Ye missed!")
                            elif ammo1<1:
                                print("Yer out of ammunition!")
                                PlayerTurn_vs_Bandits()
                        else:
                            print("Ye don't have that weapon!")
                            PlayerTurn_vs_Bandits()

                    #Hand Crossbow
                    elif weapon == "hand crossbow":
                        hand_xbow_damtype="piercing"
                        if "hand crossbow" == weapon2:
                            attack_roll = random.randint(5,20)+mod_dex
                            ammo1=ammo1-1
                            if ammo1>0:
                                if attack_roll>=bandit_ac:
                                    bandit1_hp = bandit1_hp - random.randint(1,6)
                                    print("Ye hit the Bandit in Red with yer crossbow! Good shot! It has %d HP left!" % (bandit1_hp))
                                    if bandit1_hp<1:
                                        print("The Bandit in Red falls to the floor!")
                                elif attack_roll<bandit_ac:
                                    print("Ye missed!")
                            elif ammo1<1:
                                print("Yer out of ammunition!")
                                PlayerTurn_vs_Bandits()
                        else:
                            print("Well that's not a weapon that's available to you, sonny!")
                            PlayerTurn_vs_Bandits()

                    elif weapon not in all_weapons:
                        print("That's not a valid option!")
                        PlayerTurn_vs_Bandits()
            elif atk_choice=="blue":
                if bandit2_hp<1:
                    print("The one's already dead!")
                    PlayerTurn_vs_Bandits()
                else:
                    weapon = input("What will ye attack with? (%s or %s)\n" % (weapon1,weapon2)).lower()

                    #longsword
                    if weapon == "longsword":
                        longsword_damtype="slashing"
                        if "longsword" == weapon1 or "longsword" == weapon2:
                            attack_roll = random.randint(5,20)+mod_str
                            if attack_roll>=bandit_ac:
                                bandit2_hp = bandit2_hp - random.randint(1,8)
                                print("Ye hit the Bandit in Blue! He has %d HP left!" % (bandit2_hp))
                                if bandit2_hp<1:
                                    print("The Bandit in Blue falls to the floor!")
                            elif attack_roll<bandit_ac:
                                print("Ye missed!") 
                        else:
                            print("Ye don't have a %s!" % (weapon))
                            PlayerTurn_vs_Bandits()

                    #shortsword
                    if weapon == "shortsword":
                        shortsword_damtype="piercing"
                        if "shortsword" == weapon1:
                            attack_roll = random.randint(5,20)+mod_str
                            if attack_roll>=bandit_ac:
                                bandit2_hp = bandit2_hp - random.randint(1,8)
                                print("Ye hit the Bandit in Blue! He has %d HP left!" % (bandit2_hp))
                                if bandit2_hp<1:
                                    print("The Bandit in Blue falls to the floor!")
                            elif attack_roll<bandit_ac:
                                print("Ye missed!")
                        else:
                            print("Ye don't have a %s!" % (weapon))
                            PlayerTurn_vs_Bandits()

                    #Morningstar
                    elif weapon == "morningstar":
                        morningstar_damtype="piercing"
                        if "morningstar" == weapon1:
                            attack_roll = random.randint(5,20)+mod_str
                            if attack_roll>=bandit_ac:
                                bandit2_hp = bandit2_hp - random.randint(1,8)
                                print("Ye hit the Bandit in Blue! He has %d HP left!" % (bandit2_hp))
                                if bandit2_hp<1:
                                    print("The Bandit in Blue falls to the floor!")
                            elif attack_roll<bandit_ac:
                                print("Ye missed!")
                        else:
                            print("Ye don't have a %s!" % (weapon))
                            PlayerTurn_vs_Bandits()

                    #Sling
                    if weapon == "sling":
                        sling_damtype="bludgeoning"
                        if "sling" == weapon2:
                            attack_roll = random.randint(5,20)+mod_dex
                            ammo1=ammo1-1
                            if ammo1>0:
                                if attack_roll>=bandit_ac:
                                    bandit2_hp = bandit2_hp - random.randint(1,4)
                                    print("Ye hit the Bandit in Blue! He has %d HP left!" % (bandit2_hp))
                                if bandit2_hp<1:
                                    print("The Bandit in Blue falls to the floor!")
                                elif attack_roll<bandit_ac:
                                    print("Ye missed!")
                            elif ammo1<1:
                                print("Yer out of ammunition!")
                                PlayerTurn_vs_Bandits()
                        else:
                            print("Ye don't have a %s!" % (weapon))
                            PlayerTurn_vs_Bandits()

                    #Quarterstaff
                    elif weapon == "quarterstaff" or weapon == "quarter staff":
                        quarterstaff_damtype="bludgeoning"
                        if "quarterstaff" == weapon1:
                            attack_roll = random.randint(5,20)+mod_str
                            if attack_roll>=bandit_ac:
                                bandit2_hp = bandit2_hp - random.randint(1,6)
                                print("Ye hit the Bandit in Blue! He has %d HP left!" % (bandit2_hp))
                                if bandit2_hp<1:
                                    print("The Bandit in Blue falls to the floor!")
                            elif attack_roll<bandit_ac:
                                print("Ye missed!")
                        else:
                            print("Ye don't have a %s!"%(weapon))
                            PlayerTurn_vs_Bandits()

                    #Dagger
                    elif weapon == "dagger":
                        dagger_damtype="piercing"
                        if "dagger" == weapon1:
                            attack_roll = random.randint(5,20)+mod_str
                            if attack_roll>=bandit_ac:
                                    bandit2_hp = bandit2_hp - random.randint(1,6)
                                    print("Ye hit the Bandit in Blue! He has %d HP left!" % (bandit2_hp))
                                    if bandit2_hp<1:
                                        print("The Bandit in Blue falls to the floor!")
                            elif attack_roll<bandit_ac:
                                print("Ye missed!")
                        else:
                            print("Ye don't have that weapon!")
                            PlayerTurn_vs_Bandits()

                    #Light Crossbow
                    elif weapon == "light crossbow":
                        light_xbow_damtype="piercing"
                        if "light crossbow" == weapon2:
                            attack_roll = random.randint(5,20)+mod_dex
                            ammo1=ammo1-1
                            if ammo1>0:
                                if attack_roll>=bandit_ac:
                                    bandit2_hp = bandit2_hp - random.randint(1,6)
                                    print("Ye hit the Bandit in Blue! He has %d HP left!" % (bandit2_hp))
                                if bandit2_hp<1:
                                    print("The Bandit in Blue falls to the floor!")
                                elif attack_roll<bandit_ac:
                                    print("Ye missed!")
                            elif ammo1<1:
                                print("Yer out of ammunition!")
                                PlayerTurn_vs_Bandits()
                        else:
                            print("Ye don't have that weapon!")
                            PlayerTurn_vs_Bandits()

                    #Hand Crossbow
                    elif weapon == "hand crossbow":
                        hand_xbow_damtype="piercing"
                        if "hand crossbow" == weapon2:
                            attack_roll = random.randint(5,20)+mod_dex
                            ammo1=ammo1-1
                            if ammo1>0:
                                if attack_roll>=bandit_ac:
                                    bandit2_hp = bandit2_hp - random.randint(1,6)
                                    print("Ye hit the Bandit in Blue! He has %d HP left!" % (bandit2_hp))
                                    if bandit2_hp<1:
                                        print("The Bandit in Blue falls to the floor!")
                                elif attack_roll<bandit_ac:
                                    print("Ye missed!")
                            elif ammo1<1:
                                print("Yer out of ammunition!")
                                PlayerTurn_vs_Bandits()
                        else:
                            print("Well that's not a weapon that's available to you, sonny!")
                            PlayerTurn_vs_Bandits()

                    elif weapon not in all_weapons:
                        print("That's not a valid option!")
                        PlayerTurn_vs_Bandits()
                    
            elif atk_choice != "red" or atk_choice != "blue":
                print("Enter the color of their robes to choose!")
                PlayerTurn_vs_Bandits()
            
        elif action == weapon1 or action == weapon2:
            print("Ya jumped the gun there sonny, I don't even know if you want to attack!")
            PlayerTurn_vs_Bandits()

        elif action == "run" or action == "run away":
            run_chance=random.randint(1,40)
            if run_chance>7:
                print("Ye tried to run, but nay! The bandits followed ye!")
            elif run_chance<8:
                PostBandit2_run()
            
        elif action == "talk" or action == "reason":
            print("You try to reason with the bandits, but they're dead-set on getting yer gold!")
            
        elif action == "spell" or action == "magic":
            spell=input("Which spell will ye use? (%s or %s) \n" % (spell1,spell2)).lower()

            #None
            if spell == "none":
                print("Ye aren't a wizard, are ye?")
                PlayerTurn_vs_Bandits()

            #Ray of Sickness
            elif spell == "ray of sickness":
                if spell_slot>2:
                    print("Yer out of spell slots!")
                    PlayerTurn_vs_Bandits()
                elif "ray of sickness" == spell1 or "ray of sickness" == spell2:
                    attack_roll = random.randint(5,20)+mod_int
                    if attack_roll>=bandit_ac:
                        spell_slot=spell_slot+1
                        color=input("Will ye attack the Bandit in Red or in Blue?\n")
                        if color == "red":
                            bandit1_hp = bandit1_hp - (random.randint(1,8)+random.randint(1,8))
                            poison=13
                            bandit_con_save=random.randint(1,20)+bandit_mod_con
                            if poison>bandit_con_save:
                                bandit1_hp=bandit1_hp-3
                                print("A beam of sickening green smog funnels from the tips of yer fingers, then dashes into the heart of the Bandit in Red! He has %d HP left!" % (bandit1_hp))
                                if bandit1_hp<1:
                                    print("The Bandit in Red falls to the floor!")
                            else:
                                print("A beam of sickening green smog funnels from the tips of yer fingers, then dashes into the heart of the Bandit in Red! He has %d HP left!" % (bandit1_hp))
                                if bandit1_hp<1:
                                    print("The Bandit in Red falls to the floor!")
                        elif color == "blue":
                            bandit2_hp = bandit2_hp - (random.randint(1,8)+random.randint(1,8))
                            poison=13
                            bandit_con_save=random.randint(1,20)+bandit_mod_con
                            if poison>bandit_con_save:
                                bandit2_hp=bandit2_hp-3
                                print("A beam of sickening green smog funnels from the tips of yer fingers, then dashes into the heart of the Bandit in Blue! He has %d HP left!" % (bandit2_hp))
                                if bandit2_hp<1:
                                    print("The Bandit in Blue falls to the floor!")
                            else:
                                print("A beam of sickening green smog funnels from the tips of yer fingers, then dashes into the heart of the Bandit in Blue! He has %d HP left!" % (bandit2_hp))
                                if bandit2_hp<1:
                                    print("The Bandit in Blue falls to the floor!")
                        else:
                            print("I said the color of their robes!")
                            PlayerTurn_vs_Bandits()
                    elif attack_roll<bandit_ac:
                        print("Ye missed!")
                else:
                    print("Ye don't have that spell!")
                    PlayerTurn_vs_Bandits()

            #Witch Bolt
            elif spell == "witch bolt":
                if spell_slot>2:
                    print("Yer out of spell slots!")
                    PlayerTurn_vs_Bandits()
                elif "witch bolt" == spell1 or "witch bolt" == spell2:
                    attack_roll = random.randint(5,20)+mod_int
                    if attack_roll>=bandit_ac:
                        spell_slot=spell_slot+1
                        color=input("Will ye attack the Bandit in Red or in Blue?\n")
                        if color == "red":
                            bandit1_hp = bandit1_hp - random.randint(1,12)
                            print("From the palm of yer hand emerges a ball of electricity. It grows and festers for some time, until it is finally released, shocking the Bandit in Red and throwing him across the room! It has %d HP left!" % (bandit1_hp))
                            if bandit1_hp<1:
                                print("The Bandit in Red falls to the floor!")
                        elif color == "blue":
                            bandit2_hp = bandit2_hp - random.randint(1,12)
                            print("From the palm of yer hand emerges a ball of electricity. It grows and festers for some time, until it is finally released, shocking the Bandit in Blue and throwing him across the room! It has %d HP left!" % (bandit2_hp))
                        
                        else:
                            print("I said the color of their robes!")
                            PlayerTurn_vs_Bandits()
                    elif attack_roll<bandit_ac:
                        print("Ye missed!")
                else:
                    print("Ye don't have that spell!")
                    PlayerTurn_vs_Bandits()

            #cloud of daggers
            elif spell == "cloud of daggers":
                if spell_slot>2:
                    print("Yer out of spell slots!")
                    PlayerTurn_vs_Bandits()
                else:
                    if "cloud of daggers" == spell1 or "cloud of daggers" == spell2:
                        attack_roll = random.randint(5,20)+mod_int
                        if attack_roll>=bandit_ac:
                            spell_slot=spell_slot+1
                            color = input("Will ye attack the Bandit in Red or in Blue?\n")
                            if color == "red":
                                bandit1_hp = bandit1_hp - (random.randint(1,4)+random.randint(1,4)+random.randint(1,4)+random.randint(1,4))
                                print("Above Bandit in Red appears a five by five foot cube of dagger, which rains down upon him, slashing many fresh wounds into the bandit's flesh! It has %d HP left!" % (bandit1_hp))
                                if bandit1_hp<1:
                                    print("The Bandit in Red falls to the floor!")
                            elif color == "blue":
                                bandit2_hp = bandit2_hp - (random.randint(1,4)+random.randint(1,4)+random.randint(1,4)+random.randint(1,4))
                                print("Above Bandit in Blue appears a five by five foot cube of dagger, which rains down upon him, slashing many fresh wounds into the bandit's flesh! It has %d HP left!" % (bandit2_hp))
                                if bandit2_hp<1:
                                    print("The Bandit in Blue falls to the floor!")
                            else:
                                print("I said the color of their robes!")
                                PlayerTurn_vs_Bandits()
                        elif attack_roll<bandit_ac:
                            print("Ye missed!")
                    else:
                        print("Ye don't have that spell!")
                        PlayerTurn_vs_Bandits()

            #scorching ray
            elif spell == "scorching ray":
                if spell_slot>2:
                    print("Yer out of spell slots!")
                    PlayerTurn_vs_Bandits()
                else:
                    if "scorching ray" == spell1 or "scorching ray" == spell2:
                        attack_roll = random.randint(5,20)+mod_int
                        if attack_roll>=bandit_ac:
                            spell_slot=spell_slot+1
                            color = input("Will ye attack the Bandit in Red or in Blue?\n")
                            if color == "red":
                                bandit1_hp = bandit1_hp - (random.randint(1,6)+random.randint(1,6))
                                print("You generate a beam of fire in your closed fist, and then release it into the Bandit in Red's face! It has %d HP left!" % (bandit1_hp))
                                if bandit1_hp<1:
                                    print("The Bandit in Red falls to the floor!")
                            elif color == "blue":
                                bandit2_hp = bandit2_hp - (random.randint(1,6)+random.randint(1,6))
                                print("You generate a beam of fire in your closed fist, and then release it into the Bandit in Blue's face! It has %d HP left!" % (bandit2_hp))
                                if bandit2_hp<1:
                                    print("The Bandit in Blue falls to the floor!")
                            else:
                                print("I said the color of their robes!")
                                PlayerTurn_vs_Bandits()
                        elif attack_roll<bandit_ac:
                            print("Ye missed!")
                    else:
                        print("Ye don't have that spell!")
                        PlayerTurn_vs_Bandits()
                        
            elif spell not in spell_list:
                print("That's not a spell!")
                PlayerTurn_vs_Bandits()

        elif action == "quit":
            print("Fare ye well, traveler!")
        else:
            print("That isn't something ye can do now ya see")
            PlayerTurn_vs_Bandits()
            
def BanditTurn():
    Scimitar1()
    Scimitar2()
        
def Scimitar1():
    global player_hp
    global bandit1_attack
    bandit1_attack = random.randint(1,20)
    if bandit1_attack>player_ac:
        if "slashing" in player_resistancies:
            damage=(random.randint(1,4)+1)/2
            player_hp=player_hp-damage
            print("The Bandit in Red swings his scimitar at ye, and it slashes into yer arm! Ye have", player_hp, "HP left")
        else:
            damage=(random.randint(1,4)+1)
            player_hp=player_hp-damage
            print("The Bandit in Red swings his scimitar at ye, and it slashes into yer arm! Ye have", player_hp, "HP left")
    elif bandit1_attack<=player_ac:
        damage = 0
        print("The Bandit in Red swings his scimitar at ye, but ye duck under it!")
        
def Scimitar2():
    global bandit2_attack
    global player_hp
    bandit2_attack = random.randint(1,20)
    if bandit2_attack>player_ac:
        if "slashing" in player_resistancies:
            damage=(random.randint(1,6)+1)/2
            player_hp=player_hp-damage
            print("The Bandit in Blue swings his scimitar at ye, and it slashes into yer arm! Ye have", player_hp, "HP left")
        else:
            damage=(random.randint(1,6)+1)
            player_hp=player_hp-damage
            print("The Bandit in Blue swings his scimitar at ye, and it slashes into yer arm! Ye have", player_hp, "HP left")
    elif bandit2_attack<=player_ac:
        damage = 0
        print("The Bandit in Blue swings his scimitar at ye, but ye duck under it!")
                
def PostBandit():
    global player_hp
    global player_class
    global spell_slot
    if player_class == "fighter":
        player_hp=23
    if player_class == "wizard":
        player_hp=24
    if player_class == "rogue":
        player_hp=22
    spell_slot=0
    print(("-"*25)+"Victory!"+("-"*25))
    #Reset hp based on class
    print("The bandits slump to the ground, their weapons loose in their hands. Ye did it!")
    print("Ye reach the end of the forest, and it opens up to a clearing. Ye see that the path peels off to the left or right.\n")
    print("Ye know that the cave with the treasure is to the right, but ye could also go to the left and explore.\n")
    way_to_go()

def PostBandit2_run():
    global player_hp
    global player_class
    global spell_slot
    if player_class == "fighter":
        player_hp=23
    if player_class == "wizard":
        player_hp=24
    if player_class == "rogue":
        player_hp=22
    spell_slot=0
    print(("-"*25)+"Escape!"+("-"*25))
    print("Ye succesfully escaped the bandits. Ye continue on yer way.")
    print("Ye reach the end of the forest, and it opens to a clearing. Ye see that the path peels off to the left or right.")
    print("Ye know that the cave with the treasure is to the right, but ye could also go to the left and explore.\n")
    way_to_go()
    
def way_to_go():
    path = input("Which way will ye go?\n").lower()
#Left Path
    if path == "left":
        left_path()
 
#Right Path
    elif path == "right":
        right_path()
#If neither is chosen:  
    else:
        print("That is not a way ye can go.")
        way_to_go()
   
def left_path():
    print(("-"*25)+"Left Path"+("-"*25))
    print("Ye go down the left path, unaware of what may lie ahead...\n")
    print("Eventually, ye end up in front of a large mansion.\n")
    print("It looks dark inside, but the front doors are unlocked, and ye can't help but let yerself in.\n")
    print(("-"*25)+"Mansion"+("-"*25))
    atrium()
    
def atrium():
    print("Ye stand within the atrium. After looking around, ye see a kitchen, a set of stairs, and a closed door.\n")
    roomchoice = input("Where will ye go?(Kitchen, Stairs, Door)\n").lower()
    if roomchoice == "kitchen":
        Kitchen()
    elif roomchoice == "stairs":
        Bedroom()
    elif roomchoice == "door":
        Basement()
   
cabinets = ["paper"]

def Kitchen():
    global cabinets
    global pocket
    print(("-"*25)+"Kitchen"+("-"*25))
    print("Ye wander into the kitchen. There is nothing but dust, from what ye can see.\n")
    search_kitchen = input("Search the cabinets?\n").lower()
    if search_kitchen == "yes":
        if "paper" in pocket:
            print("Ye check the cabinets but find nothing new.")
            roomchoice = input("Where will ye go?(Atrium, Stairs, Door)\n").lower()
            if roomchoice == "atrium":
                atrium()
            elif roomchoice == "stairs":
                Bedroom()
            elif roomchoice == "door":
                Basement()
        else:
            print("Ye open a few cabinets and look inside. Within one set, ye find a slip of paper.\n")
            cabinets.remove("paper")
            pocket.append("paper")
            print("It reads: ")
            script()
            print("Confused, but intrigued, ye continue forth.\n")
            roomchoice = input("Where will ye go?(Atrium, Stairs, Door)\n").lower()
            if roomchoice == "atrium":
                atrium()
            elif roomchoice == "stairs":
                Bedroom()
            elif roomchoice == "door":
                Basement()
    elif search_kitchen == "no":
        print("-"*60)
        print("Ye leave the kitchen empty handed and continue forth.\n")
        roomchoice = input("Where will ye go?(Atrium, Stairs, Door)\n").lower()
        if roomchoice == "atrium":
            atrium()
        elif roomchoice == "stairs":
            Bedroom()
        elif roomchoice == "door":
            Basement()
    else:
        print("Now what is. that supposed to mean, sonny?")
        Kitchen()
 
def script():
    print("A being beyond ethereal...")
    print("One who fells all before it...")
    print("A long forgotten secret revealed in time...")
    print("A lost soul, seeking truth...")
    print("A legend told through the generations, never to be solved...")
    if random.randint(1,70) == 69:
        print("The only one to stop him...")
        print("The Big Boi...")
    print("~Unknown, 317 BC\n")
 
beddoor=["key"]

def Bedroom():
    global beddoor
    global pocket
    print(("-"*25)+"Bedroom"+("-"*25))
    print("Ye go up the stairs to the bedroom. The window is open, and ye jump when the wind slams the door behind ye.\n")
    search_bedroom = input("Search the bedroom?\n")
    if search_bedroom == "yes":
        if "key" in pocket:
            print("Ye don't find anything new in the room. Ye also don't stumble uponanother key.")
            roomchoice = input("Where will ye go?(Atrium, Kitchen, Door)\n").lower()
            if roomchoice == "atrium":
                atrium()
            elif roomchoice == "kitchen":
                Kitchen()
            elif roomchoice == "door":
                Basement()
        else:
            print("-"*60)
            print("Ye search the room. Ye don't find anything, but when ye go to leave, ye find a key hanging on the back of the door.\n")
            beddoor.remove("key")
            pocket.append("key")
            print("Ye take the key and leave the room.\n")
            roomchoice = input("Where will ye go?(Atrium, Kitchen, Door)\n").lower()
            if roomchoice == "atrium":
                atrium()
            elif roomchoice == "kitchen":
                Kitchen()
            elif roomchoice == "door":
                Basement()
    elif search_bedroom == "no":
        print("-"*60)
        print("Ye decide to leave the bedroom.\n")
        roomchoice = input("Where will ye go?(Atrium, Kitchen, Door)\n").lower()
        if roomchoice == "atrium":
            atrium()
        elif roomchoice == "kitchen":
            Kitchen()
        elif roomchoice == "door":
            Basement()
        
    else:
        print("I don't understand what yer tryin' to say!\n")
        Bedroom()
       
def Basement():
    global pocket
    print(("-"*25)+"Basement Entry"+("-"*25))
    print("Ye approach the door ye assume leads to the basement. Ye try to turn the door knob, but it's locked!\n")
    if "key" in pocket:
        use_key = input("Use the key?\n").lower()
        if use_key == "yes":
            print("Ye unlock the door and travel into the basement.\n")
            SubTerranea()
        elif use_key == "no":
            print("Ye decide not to use the key.\n")
            atrium()
        else:
            print("I don't know what ye mean by that, sonny. I'll lead ye back to the atrium.\n")
            atrium()
    else:
        print("Ye didn't have the key, so you head back to the atrium to clear yer mind.")
        atrium()
       
def SubTerranea():
    print(("-"*25)+"SubTerranea"+("-"*25))
    print("Ye travel down the dark stairway, lit only by a few old torches.\n")
    print("Script written in an ancient language lines the walls, but ye cannot read it\n")
    print("As ye reach the floor below, ye hear a distant growling sound.\n")
    print("Ye look around, and see numerous skeletons and weapons spread about the room.\n")
    print("Suddenly, a massive Manticore comes bounding out of the darkness at ye!\n")
    print("Ye manage to dodge its charge, but the fight has only just begun.\n")
    BossFightMant()
    
def BossFightMant():
    print(("-"*25)+"Manticore Fight"+("-"*25))
    print("The Manticore stands between you and the treasure room.")
    while True:
        if player_num>mant_num or player_num==mant_num:
            PlayerTurn_vs_Mant()
            if mant_hp<1:
                print(("-"*25)+"Victory!"+("-"*25))
                print("At last, the Manticore falls!")
                PostMant()
                break
            else:
                MantTurn()
                if player_hp<1:
                    YouDied()
                    break
                
def PlayerTurn_vs_Mant():
    global weapon1
    global weapon2
    global spell1
    global spell2
    global player_spells
    global mant_resistancies
    global mant_hp
    global player_hp
    global player_class
    global mant_mod_con
    global spell_slot
    global ammo1
    global mod_int
    global mod_dex
    global mod_str
    global spell_list
    if player_num>mant_num or player_num==mant_num:
        action = input("What will ye do now? (Attack, spell, run, talk, or quit)\n").lower()
        if action == "attack" or action == "fight" or action == "hit":
            weapon = input("What will ye attack with? (%s or %s)\n" % (weapon1,weapon2)).lower()
            
            #longsword
            if weapon == "longsword":
                longsword_damtype="slashing"
                if "longsword" == weapon1 or "longsword" == weapon2:
                    attack_roll = random.randint(5,20)+mod_str
                    if attack_roll>=mant_ac:
                        if longsword_damtype in mant_resistancies:
                            mant_hp = mant_hp - random.randint(1,8)/2
                            print("Ye hit the Manticore! It has %d HP left!" % (mant_hp))
                        else:
                            mant_hp = mant_hp - random.randint(1,8)
                            print("Ye hit the Manticore! It has %d HP left!" % (mant_hp))
                    elif attack_roll<mant_ac:
                        print("Ye missed!") 
                else:
                    print("Ye don't have a %s!" % (weapon))
                    PlayerTurn_vs_Mant()
                    
            #shortsword
            if weapon == "shortsword":
                shortsword_damtype="piercing"
                if "shortsword" == weapon1:
                    attack_roll = random.randint(5,20)+mod_str
                    if attack_roll>=mant_ac:
                        if shortsword_damtype in mant_resistancies:
                            mant_hp = mant_hp - random.randint(1,8)/2
                            print("Ye hit the Manticore! It has %d HP left!" % (mant_hp))
                        else:
                            mant_hp = mant_hp - random.randint(1,8)
                            print("Ye hit the Manticore! It has %d HP left!" % (mant_hp))
                    elif attack_roll<mant_ac:
                        print("Ye missed!")
                else:
                    print("Ye don't have a %s!" % (weapon))
                    PlayerTurn_vs_Mant()
            
            #Morningstar
            elif weapon == "morningstar":
                morningstar_damtype="piercing"
                if "morningstar" == weapon1:
                    attack_roll = random.randint(5,20)+mod_str
                    if attack_roll>=mant_ac:
                        if morningstar_damtype in mant_resistancies:
                            mant_hp = mant_hp - random.randint(1,8)/2
                            print("Ye hit the Manticore! It has %d HP left!" % (mant_hp))
                        else:
                            mant_hp = mant_hp - random.randint(1,8)
                            print("Ye hit the Manticore! It has %d HP left!" % (mant_hp))
                    elif attack_roll<mant_ac:
                        print("Ye missed!")
                else:
                    print("Ye don't have a %s!" % (weapon))
                    PlayerTurn_vs_Mant()
            
            #Sling
            if weapon == "sling":
                sling_damtype="bludgeoning"
                if "sling" == weapon2:
                    attack_roll = random.randint(5,20)+mod_dex
                    ammo1=ammo1-1
                    if ammo1>0:
                        if attack_roll>=mant_ac:
                            if sling_damtype in mant_resistancies:
                                mant_hp = mant_hp - random.randint(1,4)/2
                                print("Ye hit the Manticore! The has %d HP left!" % (mant_hp))
                            else:
                                mant_hp = mant_hp - random.randint(1,4)
                                print("Ye hit the Manticore! It has %d HP left!" % (mant_hp))
                        elif attack_roll<mant_ac:
                            print("Ye missed!")
                    elif ammo1<1:
                        print("Yer out of ammunition!")
                        PlayerTurn_vs_Mant()
                else:
                    print("Ye don't have a %s!" % (weapon))
                    PlayerTurn_vs_Mant()
            
            #Quarterstaff
            elif weapon == "quarterstaff" or weapon == "quarter staff":
                quarterstaff_damtype="bludgeoning"
                if "quarterstaff" == weapon1:
                    attack_roll = random.randint(5,20)+mod_str
                    if attack_roll>=mant_ac:
                        if quarterstaff_damtype in mant_resistancies:
                            mant_hp = mant_hp - random.randint(1,6)/2
                            print("Ye hit the Manticore! It has %d HP left!" % (mant_hp))
                        else:
                            mant_hp = mant_hp - random.randint(1,6)
                            print("Ye hit the Manticore! It has %d HP left!" % (mant_hp))
                    elif attack_roll<mant_ac:
                        print("Ye missed!")
                else:
                    print("Ye don't have a %s!"%(weapon))
                    PlayerTurn_vs_Mant()
            
            #Dagger
            elif weapon == "dagger":
                dagger_damtype="piercing"
                if "dagger" == weapon1:
                    attack_roll = random.randint(5,20)+mod_str
                    if attack_roll>=mant_ac:
                        if dagger_damtype in mant_resistancies:
                            mant_hp = mant_hp - random.randint(1,6)/2
                            print("Ye hit the Manticore! It has %d HP left!" % (mant_hp))
                        else:
                            mant_hp = mant_hp - random.randint(1,6)
                            print("Ye hit the Manticore! It has %d HP left!" % (mant_hp))
                    elif attack_roll<mant_ac:
                        print("Ye missed!")
                else:
                    print("Ye don't have that weapon!")
                    PlayerTurn_vs_Mant()
            
            #Light Crossbow
            elif weapon == "light crossbow":
                light_xbow_damtype="piercing"
                if "light crossbow" == weapon2:
                    attack_roll = random.randint(5,20)+mod_dex
                    ammo1=ammo1-1
                    if ammo1>0:
                        if attack_roll>=mant_ac:
                            if light_xbow_damtype in mant_resistancies:
                                mant_hp = mant_hp - random.randint(1,6)/2
                                print("Ye hit the Manticore with yer crossbow! Good shot! It has %d HP left!" % (mant_hp))
                            else:
                                mant_hp = mant_hp - random.randint(1,6)
                                print("Ye hit the Manticore with yer crossbow! Good shot! It has %d HP left!" % (mant_hp))
                        elif attack_roll<mant_ac:
                            print("Ye missed!")
                    elif ammo1<1:
                        print("Yer out of ammunition!")
                        PlayerTurn_vs_Mant()
                else:
                    print("Ye don't have that weapon!")
                    PlayerTurn_vs_Mant()
            
            #Hand Crossbow
            elif weapon == "hand crossbow":
                hand_xbow_damtype="piercing"
                if "hand crossbow" == weapon2:
                    attack_roll = random.randint(5,20)+mod_dex
                    ammo1=ammo1-1
                    if ammo1>0:
                        if attack_roll>=mant_ac:
                            if hand_xbow_damtype in mant_resistancies:
                                mant_hp = mant_hp - random.randint(1,6)/2
                                print("Ye hit the Mnticore with yer crossbow! Good shot! It has %d HP left!" % (mant_hp))
                            else:
                                mant_hp = mant_hp - random.randint(1,6)
                                print("Ye hit the Manticore with yer crossbow! Good shot! It has %d HP left!" % (mant_hp))
                        elif attack_roll<mant_ac:
                            print("Ye missed!")
                    elif ammo1<1:
                        print("Yer out of ammunition!")
                        PlayerTurn_vs_Mant()
                else:
                    print("Well that's not a weapon that's available to you, sonny!")
                    PlayerTurn_vs_Mant()
                    
            elif weapon not in all_weapons:
                print("That's not a valid option!")
                PlayerTurn_vs_Mant()
                
        elif action == weapon1 or action == weapon2:
            print("Ya jumped the gun there sonny, I don't even know if you want to attack!")
            PlayerTurn_vs_Mant()
            
        elif action == "run" or action == "run away":
            print("What are ye doin'? This is the boss battle! Ye can't run!")
            PlayerTurn_vs_Mant()
        elif action == "talk" or action == "reason":
            print("Ye can't speak to the Manticore! While you were busy talking, it took his turn!")
        elif action == "spell" or action == "magic":
            spell=input("Which spell will ye use? (%s or %s) \n" % (spell1,spell2)).lower()

            #None
            if spell == "none":
                print("Ye aren't a wizard, are ye?")
                PlayerTurn_vs_Bandits()
        
            #Ray of Sickness
            if spell == "ray of sickness":
                if spell_slot>2:
                    print("Yer out of spell slots!")
                    PlayerTurn_vs_Mant()
                else:
                    if "ray of sickness" == spell1 or "ray of sickness" == spell2:
                        attack_roll = random.randint(5,20)+mod_int
                        if attack_roll>=mant_ac:
                            spell_slot=spell_slot+1
                            mant_hp = mant_hp - (random.randint(1,8)+random.randint(1,8))
                            poison=13
                            mant_con_save=random.randint(1,20)+mant_mod_con
                            if poison>mant_con_save:
                                mant_hp=mant_hp-3
                            print("A beam of sickening green smog funnels from the tips of yer fingers, then dashes into the heart of the Manticore! Its has %d HP left!" % (mant_hp))
                        elif attack_roll<mant_ac:
                            print("Ye missed!")
                    else:
                        print("Ye don't have that spell!")
                        PlayerTurn_vs_Mant()

            #Witch Bolt
            if spell == "witch bolt":
                if spell_slot>2:
                    print("Yer out of spell slots!")
                    PlayerTurn_vs_Mant()
                else:
                    if "witch bolt" == spell1 or "witch bolt" == spell1:
                        attack_roll = random.randint(5,20)+mod_int
                        if attack_roll>=mant_ac:
                            spell_slot=spell_slot+1
                            mant_hp = mant_hp - random.randint(1,12)
                            print("From the palm of yer hand emerges a ball of electricity. It grows and festers for some time, until it is finally released, shocking the Manticore and throwing him across the room! It has %d HP left!" % (mant_hp))
                        elif attack_roll<mant_ac:
                            print("Ye missed!")
                    else:
                        print("Ye don't have that spell!")
                        PlayerTurn_vs_Mant()

            #cloud of daggers
            if spell == "cloud of daggers":
                if spell_slot>2:
                    print("Yer out of spell slots!")
                    PlayerTurn_vs_Mant()
                else:
                    if "cloud of daggers" == spell1 or "cloud of daggers" == spell2:
                        attack_roll = random.randint(5,20)+mod_int
                        if attack_roll>=mant_ac:
                            spell_slot=spell_slot+1
                            mant_hp = mant_hp - (random.randint(1,4)+random.randint(1,4)+random.randint(1,4)+random.randint(1,4))
                            print("Above the Manticore appears a five by five foot cube of dagger, which rains down upon him, slashing many fresh wounds into his hairy flesh! It has %d HP left!" % (mant_hp))
                        elif attack_roll<mant_ac:
                            print("Ye missed!")
                    else:
                        print("Ye don't have that spell!")
                        PlayerTurn_vs_Mant()

            #scorching ray
            if spell == "scorching ray":
                if spell_slot>2:
                    print("Yer out of spell slots!")
                    PlayerTurn_vs_Mant()
                else:
                    if "scorching ray" == spell1 or "scorching ray" == spell2:
                        attack_roll = random.randint(5,20)+mod_int
                        if attack_roll>=mant_ac:
                            spell_slot=spell_slot+1
                            mant_hp = mant_hp - (random.randint(1,6)+random.randint(1,6))
                            print("You generate a beam of fire in your closed fist, and then release it into the Manticore's gaping maw! It has %d HP left!" % (mant_hp))
                        elif attack_roll<mant_ac:
                            print("Ye missed!")
                    else:
                        print("Ye don't have that spell!")
                        PlayerTurn_vs_Mant()
            elif spell not in spell_list:
                print("That's not something ye can do now!")
                PlayerTurn_vs_Mant()
    elif action == "quit":
        print("Fare ye well, traveler!")
    else:
        print("That isn't something ye can do now ya see")
        PlayerTurn_vs_Mant()
            
def MantTurn():
    mant_turn_attack = random.randint(1,3)
    if mant_turn_attack == 1:
        result=MantMultiAttack()
    elif mant_turn_attack == 2:
        result=MantBite()
    elif mant_turn_attack == 3:
        result=MantClaws()
        
#MultiAttack
def MantMultiAttack():
    global player_hp
    global mant_hp
    mant_attack = random.randint(5,20)
    if mant_attack + 2>player_ac:
        if "piercing" in player_resistancies and "slashing" in player_resistancies:
            damage=(random.randint(1,4)+2)/2+(random.randint(1,4)+2)/2
            player_hp=player_hp-damage
            print("The manticore lunges at ye, swinging his claws from the left side and reaching his mouth toward ye on the right! Ye have", player_hp, "HP left")
        elif "piercing" in player_resistancies or "slashing" in player_resistancies:
            damage=(random.randint(1,4)+2)/2+(random.randint(1,4)+2)
            player_hp=player_hp-damage
            print("The Manticore lunges at ye, swinging his claws from the left side and reaching his mouth toward ye on the right! Ye have", player_hp, "HP left")
        else:
            damage=(random.randint(1,4)+2)+(random.randint(1,4)+2)
            player_hp=player_hp-damage
            print("The Manticore lunges at ye, swinging his claws from the left side and reaching his mouth toward ye on the right! Ye have", player_hp, "HP left")
    elif mant_attack + 2<=player_ac:
        damage = 0
        print("The Manticore attempts to use both his claws and jaw in one mencaing attack, but he misses!")
        
#bite                  
def MantBite():
    global player_hp
    global mant_hp
    mant_attack = random.randint(5,20)
    if mant_attack + 2>player_ac:
        if "piercing" in player_resistancies:
            damage=(random.randint(1,6)+2)/2
            player_hp=player_hp-damage
            print("The Manticore bites down into yer flesh! Ye have", player_hp, "HP left")
        else:
            damage=random.randint(1,6)+2
            player_hp=player_hp-damage
            print("The Manticore bites down deep into yer flesh! Ye have", player_hp, "HP left")
    elif mant_attack + 2<=player_ac:
        damage = 0
        print("The Manticore clasps his jaw shut, but ye just barely dodge his gaping maw!")
        
#claws
def MantClaws():
    global player_hp
    global mant_hp
    mant_attack = random.randint(5,20)
    if mant_attack + 2>player_ac:
        if "slashing" in player_resistancies:
            damage=(random.randint(1,6)+2)/2
            player_hp=player_hp-damage
            print("The Manticore swings his paw at ye, leaving three slash marks! Ye have", player_hp, "HP left")
        else:
            damage=random.randint(1,6)+2
            player_hp=player_hp-damage
            print("The Manticore swings his paw at ye! That's gon' to leave a scar! Ye have", player_hp, "HP left")
    elif mant_attack + 2<=player_ac:
        damage = 0
        print("The Manticore brings down his paw, but ye sidestep quick enough to get out of the way!")   
                               
 
def PostMant():
    global wallet
    global pocket
    print("The Manticore falls to the ground, yer weapon still lodged in its side.\n")
    print("Ye walk over to the large chest the creature had been guarding.\n")
    print("Ye open it, and within ye find much gold, and a deck of cards that appears to be magic!!\n")
    wallet = wallet +100
    pocket.append("Magic Deck")
    Goyleending()
 
def right_path():
    print(("-"*25)+"Right path"+("-"*25))
    print("Ye take the right path, unaware of what may lie ahead.\n")
    print("Eventually, ye find yerself standing in front of the mouth of a large cave.\n")
    print("After checking yer surroundings, ye walk inside.\n")
    #Cave
    print(("-"*25)+"Cave"+("-"*25))
    cavemouth()
    
def cavemouth():  
    global wallet
    global pocket
    print("Using a torch ye found to light yer path, ye look around.\n")
    print("Ye see numerous stalagmites and stalagtites spread about the cave, and the sound of dripping water fills yer ears.\n")
    print("As ye look around, ye see a room on yer right and an antechamber.")
    roomchoice = input("Which way will ye go?(Room, Antechamber)\n").lower()
    if roomchoice == "room":
        minelounge()
    if roomchoice == "antechamber":
        antechamber()
        
camp = ["gold pouch"]
    
def minelounge():
    global camp
    print(("-"*25)+"Miner's Camp"+("-"*30))
    print("Ye enter the room. It appears to be some kind of miner's camp, but there doesn't seem to be much here.\n")
    search_miner = input("Search the room anyway?\n").lower()
    if search_miner == "yes":
        print("Ye search the room. Ye open a chest and find a small bag of gold. Great!\n")
        camp.remove("gold pouch")
        wallet = wallet + 25
        cavemouth()
    elif search_miner == "no":
        print("Ye decide the room isn't worth searching. Ye head on.\n")
        cavemouth()
    else:
        print("I don't know what ye mean by that!\n")
        minelounge()

def antechamber():
    print(("-"*25)+"Antechamber"+("-"*25))
    print("Ye eventually reach the antechamber. Ye notice a large figure sitting in the center.\n")
    print("You carefully approach it, being careful not to alert it.\n")
    print("However, as you get close, ye realize it is only a statue of a beast sitting there.\n")
    print("Ye go to walk on past the statue, but the Gargoyle turns its head!")
    BossFightGoyle()
    
def BossFightGoyle():
    print(("-"*25)+"Gargoyle Fight"+("-"*25))
    print("It bares its teeth at ye and growls. It doesn't seem to be speaking any language ye recognize...\n")
    print("until it says three sentences, which seem to be very rehearsed:\n")
    print("'My name is Goyle, the defender of the lost realm. The treasure you seek beyond this path carries dangers beyond your reckoning. If you wish to proceed, then prepare to die!'.")
    while True:
        if player_num>goyle_num or player_num==goyle_num:
            PlayerTurn_vs_Goyle()
            if goyle_hp<1:
                print(("-"*25)+"Victory!"+("-"*25))
                print("At last, Goyle falls! Before he goes kaput, he utters one more reckoning:")
                PostGoyle()
                break
            GoyleTurn()
            if player_hp<1:
                YouDied()
                break
                
def PlayerTurn_vs_Goyle():
    global weapon1
    global weapon2
    global spell1
    global spell2
    global player_spells
    global goyle_resistancies
    global goyle_hp
    global player_hp
    global player_class
    global goyle_mod_con
    global spell_slot
    global ammo1
    global mod_int
    global mod_dex
    global mod_str
    global spell_list
    if player_num>goyle_num or player_num==goyle_num:
        action = input("What will ye do now (Attack, spell, run, talk, or quit)\n").lower()
        if action == "attack" or action == "fight" or action == "hit":
            weapon = input("What will ye attack with? (%s or %s) \n" % (weapon1,weapon2)).lower()
            
            #longsword
            if weapon == "longsword":
                longsword_damtype="slashing"
                if "longsword" == weapon1 or "longsword" == weapon2:
                    attack_roll = random.randint(5,20)+mod_str
                    if attack_roll>=goyle_ac:
                        if longsword_damtype in goyle_resistancies:
                            goyle_hp = goyle_hp - random.randint(1,8)/2
                            print("Ye hit Goyle! Goyle has %d HP left!" % (goyle_hp))
                        else:
                            goyle_hp = goyle_hp - random.randint(1,8)
                            print("Ye hit Goyle! Goyle has %d HP left!" % (goyle_hp))
                    elif attack_roll<goyle_ac:
                        print("Ye missed!") 
                else:
                    print("Ye don't have a %s!" % (weapon))
                    PlayerTurn_vs_Goyle()
                    
            #shortsword
            if weapon == "shortsword":
                shortsword_damtype="piercing"
                if "shortsword" == weapon1:
                    attack_roll = random.randint(5,20)+mod_str
                    if attack_roll>=goyle_ac:
                        if shortsword_damtype in goyle_resistancies:
                            goyle_hp = goyle_hp - random.randint(1,8)/2
                            print("Ye hit Goyle! Goyle has %d HP left!" % (goyle_hp))
                        else:
                            goyle_hp = goyle_hp - random.randint(1,8)
                            print("Ye hit Goyle! Goyle has %d HP left!" % (goyle_hp))
                    elif attack_roll<goyle_ac:
                        print("Ye missed!")
                else:
                    print("Ye don't have a %s!" % (weapon))
                    PlayerTurn_vs_Goyle()
            
            #Morningstar
            elif weapon == "morningstar":
                morningstar_damtype="piercing"
                if "morningstar" == weapon1:
                    attack_roll = random.randint(5,20)+mod_str
                    if attack_roll>=goyle_ac:
                        if morningstar_damtype in goyle_resistancies:
                            goyle_hp = goyle_hp - random.randint(1,8)/2
                            print("Ye hit Goyle! Goyle has %d HP left!" % (goyle_hp))
                        else:
                            goyle_hp = goyle_hp - random.randint(1,8)
                            print("Ye hit Goyle! Goyle has %d HP left!" % (goyle_hp))
                    elif attack_roll<goyle_ac:
                        print("Ye missed!")
                else:
                    print("Ye don't have a %s!" % (weapon))
                    PlayerTurn_vs_Goyle()
            
            #Sling
            if weapon == "sling":
                sling_damtype="bludgeoning"
                if "sling" == weapon2:
                    attack_roll = random.randint(5,20)+mod_dex
                    ammo1=ammo1-1
                    if ammo1>0:
                        if attack_roll>=goyle_ac:
                            if sling_damtype in goyle_resistancies:
                                goyle_hp = goyle_hp - random.randint(1,4)/2
                                print("Ye hit Goyle! Goyle has %d HP left!" % (goyle_hp))
                            else:
                                goyle_hp = goyle_hp - random.randint(1,4)
                                print("Ye hit Goyle! Goyle has %d HP left!" % (goyle_hp))
                        elif attack_roll<goyle_ac:
                            print("Ye missed!")
                    elif ammo1<1:
                        print("Yer out of ammunition!")
                        PlayerTurn_vs_Goyle()
                else:
                    print("Ye don't have a %s!" % (weapon))
                    PlayerTurn_vs_Goyle()
            
            #Quarterstaff
            elif weapon == "quarterstaff" or weapon == "quarter staff":
                quarterstaff_damtype="bludgeoning"
                if "quarterstaff" == weapon1:
                    attack_roll = random.randint(5,20)+mod_str
                    if attack_roll>=goyle_ac:
                        if quarterstaff_damtype in goyle_resistancies:
                            goyle_hp = goyle_hp - random.randint(1,6)/2
                            print("Ye hit Goyle! Goyle has %d HP left!" % (goyle_hp))
                        else:
                            goyle_hp = goyle_hp - random.randint(1,6)
                            print("Ye hit Goyle! Goyle has %d HP left!" % (goyle_hp))
                    elif attack_roll<goyle_ac:
                        print("Ye missed!")
                else:
                    print("Ye don't have a %s!"%(weapon))
                    PlayerTurn_vs_Goyle()
            
            #Dagger
            elif weapon == "dagger":
                dagger_damtype="piercing"
                if "dagger" == weapon1:
                    attack_roll = random.randint(5,20)+mod_str
                    if attack_roll>=goyle_ac:
                        if dagger_damtype in goyle_resistancies:
                            goyle_hp = goyle_hp - random.randint(1,6)/2
                            print("Ye hit Goyle! Goyle has %d HP left!" % (goyle_hp))
                        else:
                            goyle_hp = goyle_hp - random.randint(1,6)
                            print("Ye hit Goyle! Goyle has %d HP left!" % (goyle_hp))
                    elif attack_roll<goyle_ac:
                        print("Ye missed!")
                else:
                    print("Ye don't have that weapon!")
                    PlayerTurn_vs_Goyle()
            
            #Light Crossbow
            elif weapon == "light crossbow":
                light_xbow_damtype="piercing"
                if "light crossbow" == weapon2:
                    attack_roll = random.randint(5,20)+mod_dex
                    ammo1=ammo1-1
                    if ammo1>0:
                        if attack_roll>=goyle_ac:
                            if light_xbow_damtype in goyle_resistancies:
                                goyle_hp = goyle_hp - random.randint(1,6)/2
                                print("Ye hit Goyle with yer crossbow! Good shot! Goyle has %d HP left!" % (goyle_hp))
                            else:
                                goyle_hp = goyle_hp - random.randint(1,6)
                                print("Ye hit Goyle with yer crossbow! Good shot! Goyle has %d HP left!" % (goyle_hp))
                        elif attack_roll<goyle_ac:
                            print("Ye missed!")
                    elif ammo1<1:
                        print("Yer out of ammunition!")
                        PlayerTurn_vs_Goyle()
                else:
                    print("Ye don't have that weapon!")
                    PlayerTurn_vs_Goyle()
            
            #Hand Crossbow
            elif weapon == "hand crossbow":
                hand_xbow_damtype="piercing"
                if "hand crossbow" == weapon2:
                    attack_roll = random.randint(5,20)+mod_dex
                    ammo1=ammo1-1
                    if ammo1>0:
                        if attack_roll>=goyle_ac:
                            if hand_xbow_damtype in goyle_resistancies:
                                goyle_hp = goyle_hp - random.randint(1,6)/2
                                print("Ye hit Goyle with yer crossbow! Good shot! Goyle has %d HP left!" % (goyle_hp))
                            else:
                                goyle_hp = goyle_hp - random.randint(1,6)
                                print("Ye hit Goyle with yer crossbow! Good shot! Goyle has %d HP left!" % (goyle_hp))
                        elif attack_roll<goyle_ac:
                            print("Ye missed!")
                    elif ammo1<1:
                        print("Yer out of ammunition!")
                        PlayerTurn_vs_Goyle()
                else:
                    print("Well that's not a weapon that's available to you, sonny!")
                    PlayerTurn_vs_Goyle()
                    
            elif weapon not in all_weapons:
                print("That's not a valid option!")
                PlayerTurn_vs_Goyle()
                
        elif action == weapon1 or action == weapon2:
            print("Ya jumped the gun there sonny, I don't even know if you want to attack!")
            PlayerTurn_vs_Goyle()
            
        elif action == "run" or action == "run away":
            print("What are ye doin'? This is the boss battle! Ye can't run!")
            PlayerTurn_vs_Goyle()
        elif action == "talk" or action == "reason":
            print("Ye can't speak to Goyle! While you were busy talking, Goyle took his turn!")
        elif action == "spell" or action == "magic":
            spell=input("Which spell will ye use? (%s or %s)\n" % (spell1,spell2)).lower()
            
            #None
            if spell == "none":
                print("Ye aren't a wizard, are ye?")
            
            #Ray of Sickness
            if spell == "ray of sickness":
                if spell_slot>2:
                    print("Yer out of spell slots!")
                    PlayerTurn_vs_Goyle()
                else:
                    if "ray of sickness" == spell1 or "ray of sickness" == spell2:
                        attack_roll = random.randint(5,20)+mod_int
                        if attack_roll>=goyle_ac:
                            spell_slot=spell_slot+1
                            goyle_hp = goyle_hp - (random.randint(1,8)+random.randint(1,8))
                            poison=13
                            goyle_con_save=random.randint(1,20)+goyle_mod_con
                            if poison>goyle_con_save:
                                goyle_hp=goyle_hp-3
                            print("A beam of sickening green smog funnels from the tips of yer fingers, then dashes into the heart of Goyle! Goyle has %d HP left!" % (goyle_hp))
                        elif attack_roll<goyle_ac:
                            print("Ye missed!")
                    else:
                        print("Ye don't have that spell!")
                        PlayerTurn_vs_Goyle()

            #Witch Bolt
            if spell == "witch bolt":
                if spell_slot>2:
                    print("Yer out of spell slots!")
                    PlayerTurn_vs_Goyle()
                else:
                    if "witch bolt" == spell1 or "witch bolt" == spell1:
                        attack_roll = random.randint(5,20)+mod_int
                        if attack_roll>=goyle_ac:
                            spell_slot=spell_slot+1
                            goyle_hp = goyle_hp - random.randint(1,12)
                            print("From the palm of yer hand emerges a ball of electricity. It grows and festers for some time, until it is finally released, shocking Goyle and throwing him across the room! Goyle has %d HP left!" % (goyle_hp))
                        elif attack_roll<goyle_ac:
                            print("Ye missed!")
                    else:
                        print("Ye don't have that spell!")
                        PlayerTurn_vs_Goyle()

            #cloud of daggers
            if spell == "cloud of daggers":
                if spell_slot>2:
                    print("Yer out of spell slots!")
                    PlayerTurn_vs_Goyle()
                else:
                    if "cloud of daggers" == spell1 or "cloud of daggers" == spell2:
                        attack_roll = random.randint(5,20)+mod_int
                        if attack_roll>=goyle_ac:
                            spell_slot=spell_slot+1
                            goyle_hp = goyle_hp - (random.randint(1,4)+random.randint(1,4)+random.randint(1,4)+random.randint(1,4))
                            print("Above Goyle appears a five by five foot cube of dagger, which rains down upon him, slashing many fresh wounds into his stony flesh! Goyle has %d HP left!" % (goyle_hp))
                        elif attack_roll<goyle_ac:
                            print("Ye missed!")
                    else:
                        print("Ye don't have that spell!")
                        PlayerTurn_vs_Goyle()

            #scorching ray
            if spell == "scorching ray":
                if spell_slot>2:
                    print("Yer out of spell slots!")
                    PlayerTurn_vs_Goyle()
                else:
                    if "scorching ray" == spell1 or "scorching ray" == spell2:
                        attack_roll = random.randint(5,20)+mod_int
                        if attack_roll>=goyle_ac:
                            spell_slot=spell_slot+1
                            goyle_hp = goyle_hp - (random.randint(1,6)+random.randint(1,6))
                            print("You generate a beam of fire in your closed fist, and then release it into Goyle's gaping maw! Goyle has %d HP left!" % (goyle_hp))
                        elif attack_roll<goyle_ac:
                            print("Ye missed!")
                    else:
                        print("Ye don't have that spell!")
                        PlayerTurn_vs_Goyle()
                        
            elif spell not in spell_list:
                print("That's not something ye can do now!")
                PlayerTurn_vs_Goyle()
        elif action == "quit":
            print("Fare ye well, traveler!")
        else:
            print("That isn't something ye can do now ya see")
            PlayerTurn_vs_Goyle()
            
def GoyleTurn():
    goyle_turn_attack = random.randint(1,3)
    if goyle_turn_attack == 1:
        result=GoyleMultiAttack()
    elif goyle_turn_attack == 2:
        result=GoyleBite()
    elif goyle_turn_attack == 3:
        result=GoyleClaws()
        
#MultiAttack
def GoyleMultiAttack():
    global player_hp
    global goyle_hp
    goyle_attack = random.randint(1,20)
    if goyle_attack + 2>player_ac:
        if "piercing" in player_resistancies and "slashing" in player_resistancies:
            damage=(random.randint(1,4)+2)/2+(random.randint(1,4)+2)/2
            player_hp=player_hp-damage
            print("Goyle lunges at ye, swinging his claws from the left side and reaching his mouth toward ye on the right! Ye have", player_hp, "HP left")
        elif "piercing" in player_resistancies or "slashing" in player_resistancies:
            damage=(random.randint(1,4)+2)/2+(random.randint(1,4)+2)
            player_hp=player_hp-damage
            print("Goyle lunges at ye, swinging his claws from the left side and reaching his mouth toward ye on the right! Ye have", player_hp, "HP left")
        else:
            damage=(random.randint(1,4)+2)+(random.randint(1,4)+2)
            player_hp=player_hp-damage
            print("Goyle lunges at ye, swinging his claws from the left side and reaching his mouth toward ye on the right! Ye have", player_hp, "HP left")
    elif goyle_attack + 2<=player_ac:
        damage = 0
        print("Goyle attempts to use both his claws and jaw in one mencaing attack, but he misses!")
        
#bite                  
def GoyleBite():
    global player_hp
    global goyle_hp
    goyle_attack = random.randint(1,20)
    if goyle_attack + 2>player_ac:
        if "piercing" in player_resistancies:
            damage=(random.randint(1,6)+2)/2
            player_hp=player_hp-damage
            print("Goyle bites down into yer flesh! Ye have", player_hp, "HP left")
        else:
            damage=random.randint(1,6)+2
            player_hp=player_hp-damage
            print("Goyle bites down deep into yer flesh! Ye have", player_hp, "HP left")
    elif goyle_attack + 2<=player_ac:
        damage = 0
        print("Goyle clasps his jaw shut, but ye just barely dodge his gaping maw!")
        
#claws
def GoyleClaws():
    global player_hp
    global goyle_hp
    goyle_attack = random.randint(1,20)
    if goyle_attack + 2>player_ac:
        if "slashing" in player_resistancies:
            damage=(random.randint(1,6)+2)/2
            player_hp=player_hp-damage
            print("Goyle swings his paw at ye, leaving three slash marks! Ye have", player_hp, "HP left")
        else:
            damage=random.randint(1,6)+2
            player_hp=player_hp-damage
            print("Goyle swings his paw at ye! That's gon' to leave a scar! Ye have", player_hp, "HP left")
    elif goyle_attack + 2<=player_ac:
        damage = 0
        print("Goyle brings down his paw, but ye sidestep quick enough to get out of the way!")
        
def PostGoyle():
    print("'If ye have been strong enough to defeat me, " + player_name + ", you may be able to weild the power inside. But know that if you don't possess the power of a hero, you will bring ruin to us all.'\n")
    print("Goyle's eyes close, and he crumbles into pieces.")
    choose = input("Do you believe yerself the hero of this land? Will you enter the room, and ignore Goyle's warning?").lower()
    if choose == "yes":
        print("Ye head into the next room and open the chest. Within ye find multitudes of treasures made from precious metals, but there's one item that stands out.\n")
        print("A sword lies in the middle of the chest, eminating with a magic yellow glow. Ye have found the legendary Sword of Thunder!")
        print("Ye lift the sword, and feel the immense power rushing through yer body.\n")
        print("Ye nearly lose control - ye grasp the blade with both yer hands and channel all yer heroism...")
        whichend=random.randint(1,35)
        if whichend>=10:
            Goyleending1()
        else:
            Goylebadending()
    if choose == "no":
        Goyleending()

    
def Goyleending1():
    global weapon1
    global weapon2
    global weapon3
    global weapon4
    global quest1
    print("Until, suddenly, whatever power lies in this sword is tame. You step outside and raise the sword in the air --\n")
    print("A shock of lightning comes down, and ye know ye can use this power for good")
    print("Ye gained the Sword of Lightning!")
    if weapon1 == "blank":
        weapon1 == "Sword of Lightning"
    elif weapon2 == "blank":
        weapon2 == "Sword of Lightning"
    elif weapon3 == "blank":
        weapon3 == "Sword of Lightning"
    elif weapon4 == "blank":
        weapon4 == "Sword of Lightning"
    Goyleending()

def Goyleending():
    quest1 = "complete"
    print("Ye return to the village ye came from and spread yer story of bandits and beasts.\n")
    print("Everybody is amazed, and the shopkeeper invites ye into his shop...\n")
    
def Goylebadending():
    print("But the blade gets the best of ye. You feel a shock ring through yer body, as yer mind is no longer yer own.\n")
    print("By trying to be the hero, ye may have just become everybody's downfall...")
    display(HTML("<H2>THE END<H2>"))
    print("Thanks fer playing! You got the bad ending, but play again! Ye never know what might happen!")
    QuestChoice()
#-------------------------------------------------------------------------------------------------------

from tkinter import *
root = Tk()
root.title("Quest!")
root.geometry("800x600")
root.mainloop()

display(HTML("<H1>QUEST: A DnD Simulation<H1>"))
print("Welcome adventurer! Welcome to QUEST! My name be Rugreac Garrick, yer Dwarven guide to these lands! \nReady to start yer adventure?\n")
Startup()
# Out:
# <H1>QUEST: A DnD Simulation<H1>
# Welcome adventurer! Welcome to QUEST! My name be Rugreac Garrick, yer Dwarven guide to these lands!
# Ready to start yer adventure?
#
# Excellent! Let's begin!
# Excellent choice! The Fighter is strong and uses primarily melee attacks, but are still good with ranged weapons.
# Good choice, me friend!
# Good choice, me friend!
# Good Pick!
# Here are yer ability scores: 15 for strength, 14 for dexterity, 14 for constitution, 13 for charisma, 10 for intelligence, and 11 for wisdom!
#
# Here are yer weapons: longsword and sling.
#
# Yer armor class will be 15
#
# Ye'll start at level 2 for now!
#
# Ah, the Elves. A highly intelligent race, the Elves are masters of ranged and magic combat.
# s! Are ye ready? Yer adventure awaits! Let's go!
#
# -------------------------Quest Start!-------------------------
#
#
# After hearing rumors of treasure somewhere in the east, ye leave town in search of fortune.
#
# ...
