# %%
#Intro and Story
import random
from IPython.display import display, HTML  

player_init=3
player_hp="none"
player_lvl=2
player_xp=300
weapon1="blank"
weapon2="blank"
player_weapons=[weapon1, weapon2]
player_ac="none"
spell1="none"
spell2="none"
player_spells=[spell1, spell2]

def YouDied():
    print("You fall to the ground, yer armor torn to shreds and yer weapons broken. Ye died!\n Better luck next time!")

def Fweapon1():
    global weapon1
    weapon1=input("Now, as a fighter, yer goin' to need some weapons! I'll give ye the choice between a Longsword and a Morningstar.\n").lower()
    if weapon1 == "longsword" or weapon1 == "morningstar":
        print("Good choice, me friend!")
    else:
        print("I gave ye a choice!")
        Fweapon1()
                
def Fweapon2():
    global weapon2
    weapon2=input("Now for ranged weapons! I'll give ye the choice between a Hand Crossbow and a Sling.\n").lower()
    if weapon2=="sling" or weapon2=="hand crossbow" or weapon2== "crossbow":
        print("Good choice, me friend!")
    else:
        print("I gave ye a choice!")
        Fweapon2()
        
def Farmor():
    global mod_dex
    global player_ac
    player_ac=input("Now fer yer armor. You can choose chain mail or breastplate.\n").lower()
    if player_ac=="chain mail" or player_ac=="chanimail":
        player_ac=16
        print("Good pick!")
    elif player_ac=="breast plate" or player_ac=="breastplate":
        player_ac=14
        print("Good Pick!")
    else:
        print("I gave ye a choice!")
        Farmor()
        
def Wweapon1():
    global weapon1
    weapon1=input("Now, as a wizard, yer goin' to mainly use spells, but weapons are still important! I'll give ye the choice between a quarterstaff and a dagger.\n").lower()
    if weapon1 == "quarterstaff" or weapon1 == "dagger":
        print("Good choice, me friend!")
    else:
        print("I gave ye a choice!")
        Wweapon1()
 
def Wweapon2():
    global weapon2
    weapon2=input("Now for ranged weapons! I'll give ye the choice between a sling and a light crossbow.\n").lower()
    if weapon2 == "sling" or weapon2 == "crossbow" or weapon2 == "light crossbow":
        print("Good choice, me friend!")
    else:
        print("I gave ye a choice!")
        Wweapon2()
        
def Warmor():
    global mod_dex
    global player_ac
    player_ac=input("Now fer yer armor. You can choose leather or studded.\n").lower()
    if player_ac=="leather":
        player_ac=11
        print("Good pick!")
    elif player_ac=="studded":
        player_ac=12
        print("Good Pick!")
    else:
        print("I gave ye a choice!")
        Warmor()

def Wspells():
    global spell1
    global spell2
    print("Now, as a wizard, ye'll need spells to cast! Choose 1 of the following spells:")
    spell_choices1=["ray of sickness","witch bolt"]
    spell1=input("Ye can have ray of sickness or witch bolt.\n").lower()
    if spell1 in spell_choices1:
        spell_choices2=["cloud of daggers", "scorching ray"]
        spell2=input("Good choice! Now ye can choose yer second spell to be either cloud of daggers or scorching ray.\n")
        if spell2 in spell_choices2:
            print("That spell be a good one!")
        else:
            print("Ye have a choice, not entire free will!")
            Wspells()
    else:
        print("Ye have a choice, not entire free will!")
        Wspells()
        
def Rweapon1():
    global weapon1
    weapon1 = input("As a rogue, yer gonna want something small but equally powerful. I'll give ye the choice between a dagger or a shortsword.\n")
    if weapon1 == "dagger" or weapon1 == "shortsword":
        print("Good choice!")
    else:
        print("I gave ye a choice!")
        Rweapon1

def Rweapon2():
    global weapon2
    weapon2 = input("Now then, yer also gonna want a ranged weapon. I'll give ye the choice between a hand crossbow or a sling.\n")
    if weapon2 == "crossbow" or weapon2 == "sling" or weapon2 == "hand crossbow":
        print("Good choice!")
    else:
        print("I gave ye a choice!")
        Rweapon2
        
def Rarmor():
    global mod_dex
    global player_ac
    player_ac=input("Now fer yer armor. You can choose leather or studded.\n").lower()
    if player_ac=="leather":
        player_ac=11
        print("Good pick!")
    elif player_ac=="studded":
        player_ac=12
        print("Good Pick!")
    else:
        print("I gave ye a choice!")
        Rarmor()
        
def PickClass():
    global player_ac
    global player_hp
    global weapon1
    global weapon2
    player_class = input("Pick a class: Fighter, Wizard, or Rogue\n").lower()
    #fighter
    if player_class == "fighter":
        print("Excellent choice! The Fighter is strong and uses primarily melee attacks, but are still good with ranged weapons.")
        stat_str=15
        mod_str=2
        stat_dex=14
        mod_dex=2
        stat_con=14
        mod_con=2
        stat_cha=13
        mod_cha=1
        stat_int=10
        mod_int=0
        stat_wis=11
        mod_wis=0
        Fweapon1()
        Fweapon2()
        Farmor()
        player_hp=20
        player_ac=player_ac+mod_dex
        print("Here are yer ability scores: %d for strength, %d for dexterity, %d for constitution, %d for charisma, %d for intelligence, and %d for wisdom!\n"%(stat_str, stat_dex, stat_con, stat_cha, stat_int, stat_wis))
        print("Here are yer weapons: %s and %s.\n"%(weapon1, weapon2))
        print("Yer aromr class will be %d\n"%(player_ac))
        print("Ye'll start at level 2 for now!\n")
        
    #wizard
    elif player_class == "wizard":
        print("Excellent choice! The Wizard is a powerful class, utilizing primarily magic based attacks.")
        stat_str=10
        mod_str=0
        stat_dex=14
        mod_dex=2
        stat_con=14
        mod_con=2
        stat_cha=11
        mod_cha=0
        stat_int=15
        mod_int=2
        stat_wis=13
        mod_wis=1
        Wweapon1()
        Wweapon2()
        Warmor()
        Wspells()
        player_hp=24
        player_ac=player_ac+mod_dex
        print("Here be yer ability scores: %d for strength, %d for dexterity, %d for constitution, %d for charisma, %d for intelligence, and %d for wisdom!\n"%(stat_str, stat_dex, stat_con, stat_cha, stat_int, stat_wis))
        print("Here be yer weapons: %s and %s.\n"%(weapon1, weapon2))
        print("Here be yer spells: %s and %s.\n"%(spell1, spell2))
        print("Yer aromr class will be %d\n"%(player_ac))
        print("Ye'll start at level 3 for now!\n")
    
    #rogue
    elif player_class == "rogue":
        print("Excellent choice! The Rogue is a sneaky class. Rogues' attacks aren't very powerful, but they are very fast.")
        stat_str=10
        mod_str=0
        stat_dex=15
        mod_dex=2
        stat_con=14
        mod_con=2
        stat_cha=11
        mod_cha=0
        stat_int=14
        mod_int=2
        stat_wis=13
        mod_wis=1
        Rweapon1()
        Rweapon2()
        Rarmor()
        player_hp = 20
        player_ac = player_ac+mod_dex
        print("Here be yer ability scores: %d for strength, %d for dexterity, %d for constitution, %d for charisma, %d for intelligence, and %d for wisdom!\n"%(stat_str, stat_dex, stat_con, stat_cha, stat_int, stat_wis))
        print("Here be yer weapons: %s and %s.\n"%(weapon1, weapon2))
        print("Yer armor class will be %d\n"%(player_ac))
        print("Ye'll start at level 2 for now!\n")

    else:
        print("Oh my! I'm afraid that's not an option. Try again!") 
        PickClass()

def PickRace():
    player_race = input("Now then...Pick a race: Human, Elf, or Dwarf\n").lower()
    if player_race == "human":
        print("Ah yes, the Human. Much like you and I, they are intelligent life forms, able to do many things")
    elif player_race == "elf":
        print("Ah, the Elves. A highly intelligent race, the Elves are masters of ranged and magic combat.")
    elif player_race == "dwarf":
        print("Hmm! The Dwarves were born from the earth and are skilled in weaponmaking. They are very strong, but lack agility")
    else:
        print("Oh my! I'm afraid that's not an option. Try again!")
        PickRace()
        
def Intro():
    print("Excellent! Let's begin!")
    PickClass()
    PickRace()
    player_name = input("Now then! What is yer name?\n")
    print(player_name+"!","Are you ready? Your adventure awaits! Let's go!")
   
def story1():
    print("-"*70)
    print(" \n")
    print("After hearing rumors of treasure somewhere in the east, you leave town in search of fortune.\n")
    print("As you travel through the forest, you feel the warm breeze through the trees, and you admire the beauty of nature.\n")
    print("You reach the end of the forest, and it opens up to a clearing. You see that the path peels off to the left or right.\n")
    way_to_go()
   
   
def way_to_go():
    path = input("Which way will you go?\n")
#Left Path
    if path == "left":
        left_path()
 
#Right Path
    elif path == "right":
        right_path()
#If neither is chosen:  
    else:
        print("That is not a way you can go.")
        way_to_go()
   
def left_path():  
    print("You go down the left path, unaware of what may lie ahead...\n")
    #Gargoyle Fight
    print("As you venture forth, you feel uneasy, as if something is watching you...\n")
    print("Suddenly, a fierce looking Gargoyle jumps out at you!\n")
    #Function for Gargoyle Fight Here
   
    #Post Gargoyle Fight
    print("With the hideous beast defeated, you continue on your way.\n")
    print("Eventually, you end up in front of a large mansion.\n")
    print("It looks dark inside, but the front doors are unlocked, and you can't help but let yourself in.\n")
    print("You stand within the atrium. After looking around, you venture into the kitchen\n")
    Kitchen()
   
def Kitchen():
    print("You wander into the kitchen. There is nothing but dust, from what you can see.")
    search_kitchen = input("Search the cabinets?\n")
    if search_kitchen == "yes":
        print("You open a few cabinets and look inside. Within one set, you find a slip of paper.\n")
        print("It reads: ")
        script()
        print("Confused, but intrigued, you continue forth.\n")
        Bedroom()
    elif search_kitchen == "no":
        print("You leave the kitchen empty handed and continue forth.\n")
        Bedroom()
    else:
        print("Invalid input. You exit the kitchen.")
        Bedroom()
 
def script():
    print("A being beyond ethereal...")
    print("One who fells all before it...")
    print("A long forgotten secret revealed in time...")
    print("A lost soul, seeking truth...")
    print("A legend told through the generations, never to be solved...")
    print("~Unknown, 317 BC")
 
def Bedroom():
    print("You go up the stairs to the bedroom. The window is open, and you jump when the wind slams the door behind you.\n")
    search_bedroom = input("Search the bedroom?\n")
    if search_bedroom == "yes":
        print("You search the room. You don't find anything, but when you go to leave, you find a key hanging on the back of the door.\n")
        print("You take the key and leave the room.\n")
        Basement()
    elif search_bedroom == "no":
        print("You go to leave, and you find a key hanging on the back of the door.\n")
        print("You take the key and leave the room.\n")
        Basement()
    else:
        print("Invalid input. You find a key on the door and exit the room.\n")
        Basement()
       
def Basement():
    print("You approach the door you assume leads to the basement. There is a lock on the door.\n")
    use_key = input("Use the key?\n")
    if use_key == "yes":
        print("You unlock the door and travel into the basement.\n")
        SubTerranea()
    elif use_key == "no":
        print("You decide not to use the key.\n")
        print("After a few minutes, you realize your mistake and unlock the door.\n")
        SubTerranea()
    else:
        print("Invalid input. You decide to use the key anyways.\n")
        SubTerranea()
       
def SubTerranea():
    print("You travel down the dark stairway, lit only by a few old torches.\n")
    print("Script written in an ancient language lines the walls, but you cannot read it\n")
    print("As you reach the floor below, you hear a distant grunting sound.\n")
    print("You look around, and see numerous skeletons and weapons spread about the room.\n")
    print("Out of the blue, a huge Flesh Golem comes sprinting out of the darkness!\n")
    print("You manage to dodge its charge, but the fight has only just begun.\n")
    #Flesh Golem Fight
   
                               
 
    #Post Golem Fight:
    print("The golem falls to the ground, your weapon still lodged in its side.\n")
    print("You walk over to the large chest the creature had been guarding.\n")
    print("You open it, and within you find a set of gem embedded armor and weapons!\n")
    ending()
 
def right_path():
    print("You take the right path, unaware of what may lie ahead.\n")
    #_____ Fight
    print("As you venture forth, you feel uneasy, as if something is watching you...\n")
    print("Suddenly, a fierce looking ____ jumps out at you!\n")
       
    #Post _______ Fight:
    print("With the hideous beast defeated, you continue on your way.\n")
    print("Eventually, you find yourself standing in front of the mouth of a large cave.\n")
    print("After checking your surroundings, you walk inside.\n")
    #Cave
    print("Using a torch you found to light your path, you look around.\n")
    print("You see numerous stalagmites and stalagtites spread about the cave, and the sound of dripping water fills your ears.\n")
    print("As you continue further into the cave, you notice a small room on your right.\n")
    miner = input("Enter the room?\n")
    if miner == "yes":
        print("You enter the room. It appears to be some kind of miner's camp.\n")
        search_miner = input("Search the room?\n")
        if search_miner == "yes":
            print("You search the room. You open a chest and find a small bag of gold. Great!\n")
            mine_continue()
        if search_miner == "no":
            print("You decide the room isn't worth searching. You head on.\n")
            mine_continue()
    elif miner == "no":
        print("You ignore the room and continue on your way.\n")
        mine_continue()
    else:
        print("Invalid input. You decide to leave the room.\n")
        mine_continue()
def mine_continue():
    print("You eventually reach a large antechamber. You notice a large figure, wearing only a loincloth, sitting in the center.\n")
    print("It is not facing you, but you can tell from its size that it's a giant.\n")
    print("You approach the creature slowly, careful not to make your presence known.\n")
    print("Despite your best efforts, the giant grunts as it looks over its shoulder towards you.\n")
    print("It stands up and grabs its club.\n")
    print("The fight is on!\n")
    #Hill Giant Fight
   
    #Post Giant Fight
    print("At last, the giant falls. You head towards the back of the antechamber, where a large chest lies.\n")
    print("You open the chest, and within you find multitudes of treasures made from precious metals!\n")
    ending()
   
   
 
def ending():
    print("You return to the village you came from and spread your story.\n")
    print("A local scribe writes your tale, and your name lives on in infamy.\n")
    display(HTML("<H2>THE END<H2>"))
    print("Thanks for playing!")
#-------------------------------------------------------------------------------------------------------
 
display(HTML("<H1>QUEST: A DnD Simulation<H1>"))
start = input("Welcome adventurer! Welcome to QUEST! Ready to start your adventure?\n").lower()
if start == "yes":
    Intro()
   
    story1()
   
else:
    print("Perhaps you are not ready yet. Come back when you are!")
