# %%
def YouDied():
    print("You fall to the ground, yer armor torn to shreds and yer weapons broken. Ye died!\n Better luck next time!")
#Delete later
player_init=3
mod_str=2
mod_dex=2
player_hp=38
player_ac=11
player_resistancies = ["Piercing"]
weapon1="longsword"
weapon2="hand crossbow"
player_weapons=[weapon1, weapon2]
spell1="none"
spell2="none"
player_spells=[spell1, spell2]
spell_slot=0
#Goyle stats
goyle_ac=12
goyle_hp=46
goyle_sp=30
goyle_fl=60
goyle_str=15
goyle_mod_str=2
goyle_dex=11
goyle_mod_dex=0
goyle_con=16
goyle_mod_con=3
goyle_int=6
goyle_mod_int=-2
goyle_wis=11
goyle_mod_wis=0
goyle_cha=7
goyle_mod_cha=-2
goyle_resistancies=["slashing"]

import random
player_num=random.randint(1,20)+player_init
goyle_num=random.randint(1,20)
#attack sequence
def PlayerTurn_vs_Goyle():
    global spell1
    global spell2
    global player_spells
    global goyle_resistancies
    global goyle_hp
    global player_hp
    global goyle_mod_con
    global spell_slot
    if player_num>goyle_num or player_num==goyle_num:
        action = input("What will ye do now?\n").lower()
        if action == "attack" or action == "fight" or action == "hit":
            weapon = input("What will ye attack with?\n").lower()
            
            #longsword
            if weapon == "longsword":
                longsword_damtype="slashing"
                if "longsword" in player_weapons:
                    attack_roll = random.randint(1,20)+mod_str
                    if attack_roll>=goyle_ac:
                        if longsword_damtype in goyle_resistancies:
                            goyle_hp = goyle_hp - random.randint(1,8)/2
                            print("Ye hit Goyle! Goyle has %d HP left!" % (goyle_hp))
                        else:
                            goyle_hp = goyle_hp - random.randint(1,8)
                            print("Ye hit Goyle! Goyle has %d HP left!" % (goyle_hp))
                    elif attack_roll<goyle_ac:
                        print("Ye missed!")     
                else:
                    print("Ye don't have a %s!" % (weapon))
            
            #shortsword
            if weapon == "shortsword":
                shortsword_damtype="piercing"
                if "shortsword" in player_weapons:
                    attack_roll = random.randint(1,20)+mod_str
                    if attack_roll>=goyle_ac:
                        if shortsword_damtype in goyle_resistancies:
                            goyle_hp = goyle_hp - random.randint(1,8)/2
                            print("Ye hit Goyle! Goyle has %d HP left!" % (goyle_hp))
                        else:
                            goyle_hp = goyle_hp - random.randint(1,8)
                            print("Ye hit Goyle! Goyle has %d HP left!" % (goyle_hp))
                    elif attack_roll<goyle_ac:
                        print("Ye missed!")
                else:
                    print("Ye don't have a %s!" % (weapon))
            
            #Morningstar
            elif weapon == "morningstar":
                morningstar_damtype="piercing"
                if "morningstar" in player_weapons:
                    attack_roll = random.randint(1,20)+mod_str
                    if attack_roll>=goyle_ac:
                        if morningstar_damtype in goyle_resistancies:
                            goyle_hp = goyle_hp - random.randint(1,8)/2
                            print("Ye hit Goyle! Goyle has %d HP left!" % (goyle_hp))
                        else:
                            goyle_hp = goyle_hp - random.randint(1,8)
                            print("Ye hit Goyle! Goyle has %d HP left!" % (goyle_hp))
                    elif attack_roll<goyle_ac:
                        print("Ye missed!")
                else:
                    print("Ye don't have a %s!" % (weapon))
            
            #Sling
            if weapon == "sling":
                sling_damtype="bludgeoning"
                if "sling" in player_weapons:
                    attack_roll = random.randint(1,20)+mod_dex
                    if attack_roll>=goyle_ac:
                        if sling_damtype in goyle_resistancies:
                            goyle_hp = goyle_hp - random.randint(1,4)/2
                            print("Ye hit Goyle! Goyle has %d HP left!" % (goyle_hp))
                        else:
                            goyle_hp = goyle_hp - random.randint(1,4)
                            print("Ye hit Goyle! Goyle has %d HP left!" % (goyle_hp))
                    elif attack_roll<goyle_ac:
                        print("Ye missed!")
                else:
                    print("Ye don't have a %s!" % (weapon))
            
            #Quarterstaff
            elif weapon == "quarterstaff" or weapon == "quarter staff":
                quarterstaff_damtype="bludgeoning"
                if "quarterstaff" in player_weapons:
                    attack_roll = random.randint(1,20)+mod_str
                    if attack_roll>=goyle_ac:
                        if quarterstaff_damtype in goyle_resistancies:
                            goyle_hp = goyle_hp - random.randint(1,6)/2
                            print("Ye hit Goyle! Goyle has %d HP left!" % (goyle_hp))
                        else:
                            goyle_hp = goyle_hp - random.randint(1,6)
                            print("Ye hit Goyle! Goyle has %d HP left!" % (goyle_hp))
                    elif attack_roll<goyle_ac:
                        print("Ye missed!")
                else:
                    print("Ye don't have that weapon!")
                    PlayerTurn_vs_Goyle
            
            #Dagger
            elif weapon == "dagger":
                dagger_damtype="piercing"
                if "dagger" in player_weapons:
                    attack_roll = random.randint(1,20)+mod_str
                    if attack_roll>=goyle_ac:
                        if dagger_damtype in goyle_resistancies:
                            goyle_hp = goyle_hp - random.randint(1,6)/2
                            print("Ye hit Goyle! Goyle has %d HP left!" % (goyle_hp))
                        else:
                            goyle_hp = goyle_hp - random.randint(1,6)
                            print("Ye hit Goyle! Goyle has %d HP left!" % (goyle_hp))
                    elif attack_roll<goyle_ac:
                        print("Ye missed!")
                else:
                    print("Ye don't have that weapon!")
                    PlayerTurn_vs_Goyle
            
            #Light Crossbow
            elif weapon == "light crossbow":
                light_xbow_damtype="piercing"
                if "light crossbow" in player_weapons:
                    attack_roll = random.randint(1,20)+mod_dex
                    if attack_roll>=goyle_ac:
                        if light_xbow_damtype in goyle_resistancies:
                            goyle_hp = goyle_hp - random.randint(1,6)/2
                            print("Ye hit Goyle with yer crossbow! Good shot! Goyle has %d HP left!" % (goyle_hp))
                        else:
                            goyle_hp = goyle_hp - random.randint(1,6)
                            print("Ye hit Goyle with yer crossbow! Good shot! Goyle has %d HP left!" % (goyle_hp))
                    elif attack_roll<goyle_ac:
                        print("Ye missed!")
                else:
                    print("Well that's not a weapon that's available to you, sonny!")
                    PlayerTurn_vs_Goyle()
            
            #Hand Crossbow
            elif weapon == "hand crossbow":
                hand_xbow_damtype="piercing"
                if "hand crossbow" in player_weapons:
                    attack_roll = random.randint(1,20)+mod_dex
                    if attack_roll>=goyle_ac:
                        if hand_xbow_damtype in goyle_resistancies:
                            goyle_hp = goyle_hp - random.randint(1,6)/2
                            print("Ye hit Goyle with yer crossbow! Good shot! Goyle has %d HP left!" % (goyle_hp))
                        else:
                            goyle_hp = goyle_hp - random.randint(1,6)
                            print("Ye hit Goyle with yer crossbow! Good shot! Goyle has %d HP left!" % (goyle_hp))
                    elif attack_roll<goyle_ac:
                        print("Ye missed!")
                else:
                    print("Well that's not a weapon that's available to you, sonny!")
                    PlayerTurn_vs_Goyle()
            else:
                print("Well that's not somethin' ye can do!")
                PlayerTurn_vs_Goyle()
        elif action in player_weapons:
            print("Ya jumped the gun there sonny, I don't even know if you want to attack!")
            PlayerTurn_vs_Goyle
        elif action == "Run".lower() or action == "Run away".lower():
            chance = random.randint(1,20)
            if chance > 10:
                print("Ye got away safely!")
                #ApproachingCave
            else:
                print("Goyle followed ye! Ye wasted yer turn running!")
                GoyleTurn()
        elif action == "talk" or action == "reason":
            print("Ye can't speak to Goyle! While you were busy talking, Goyle took his turn!")
        elif action == "spell" or action == "magic":
            spell=input("Which spell will ye use?\n").lower()
            
            #Ray of Sickness
            if spell == "ray of sickness":
                if spell_slot>2:
                    print("Yer out of spell slots!")
                    PlayerTurn_vs_Goyle()
                else:
                    spell_slot=spell_slot+1
                    if "ray of sickness" == spell1 or "ray of sickness" == spell2:
                        attack_roll = random.randint(1,20)+mod_int
                        if attack_roll>=goyle_ac:
                            goyle_hp = goyle_hp - (random.randint(1,8)+random.randint(1,8))
                            poison=13
                            goyle_con_save=random.randint(1,20)+goyle_mod_con
                            if poison>goyle_con_save:
                                goyle_hp=goyle_hp-3
                            print("A beam of sickening green smog funnels from the tips of yer fingers, then dashes into the heart of Goyle! Goyle has %d HP left!" % (goyle_hp))
                        elif attack_roll<goyle_ac:
                            print("Ye missed!")
                    else:
                        print("Ye don't have that spell!")
                        PlayerTurn_vs_Goyle()
            
            #Witch Bolt
            if spell == "witch bolt":
                if spell_slot>2:
                    print("Yer out of spell slots!")
                    PlayerTurn_vs_Goyle()
                else:
                    spell_slot=spell_slot+1
                    if "witch bolt" == spell1 or "witch bolt" == spell1:
                        attack_roll = random.randint(1,20)+mod_int
                        if attack_roll>=goyle_ac:
                            goyle_hp = goyle_hp - random.randint(1,12)
                            print("From the palm of yer hand emerges a ball of electricity. It grows and festers for some time, until it is finally released, shocking Goyle and throwing him across the room! Goyle has %d HP left!" % (goyle_hp))
                        elif attack_roll<goyle_ac:
                            print("Ye missed!")
                    else:
                        print("Ye don't have that spell!")
                        PlayerTurn_vs_Goyle()
            
            #cloud of daggers
            if spell == "cloud of daggers":
                if spell_slot>2:
                    print("Yer out of spell slots!")
                    PlayerTurn_vs_Goyle()
                else:
                    spell_slot=spell_slot+1
                    if "cloud of daggers" == spell1 or "cloud of daggers" == spell2:
                        attack_roll = random.randint(1,20)+mod_int
                        if attack_roll>=goyle_ac:
                            goyle_hp = goyle_hp - (random.randint(1,4)+random.randint(1,4)+random.randint(1,4)+random.randint(1,4))
                            print("Above Goyle appears a five by five foot cube of dagger, which rains down upon him, slashing many fresh wounds into his stony flesh! Goyle has %d HP left!" % (goyle_hp))
                        elif attack_roll<goyle_ac:
                            print("Ye missed!")
                    else:
                        print("Ye don't have that spell!")
                        PlayerTurn_vs_Goyle()
            
            #scorching ray
            if spell == "scorching ray":
                if spell_slot>2:
                    print("Yer out of spell slots!")
                    PlayerTurn_vs_Goyle()
                else:
                    spell_slot=spell_slot+1
                    if "scorching ray" == spell1 or "scorching ray" == spell2:
                        attack_roll = random.randint(1,20)+mod_int
                        if attack_roll>=goyle_ac:
                            goyle_hp = goyle_hp - (random.randint(1,6)+random.randint(1,6))
                            print("You generate a beam of fire in your closed fist, and then release it into Goyle's gaping maw! Goyle has %d HP left!" % (goyle_hp))
                        elif attack_roll<goyle_ac:
                            print("Ye missed!")
                    else:
                        print("Ye don't have that spell!")
                        PlayerTurn_vs_Goyle()
            
        elif action == "quit":
            print("Fare ye well, traveler!")
        else:
            print("That isn't something ye can do now ya see")
            PlayerTurn_vs_Goyle()
            
def GoyleTurn():
    goyle_attacknum=0
    player_attacknum=0
    goyle_turn_attack = random.randint(1,3)
    if goyle_turn_attack == 1:
        result=MultiAttack()
        goyle_attacknum=goyle_attacknum+1
        if goyle_attacknum >= player_attacknum:
            PlayerTurn_vs_Goyle()
    if goyle_turn_attack == 2:
        result=Bite()
        goyle_attacknum=goyle_attacknum+1
        if goyle_attacknum >= player_attacknum:
            PlayerTurn_vs_Goyle()
    if goyle_turn_attack == 3:
        result=Claws()
        goyle_attacknum=goyle_attacknum+1
        if goyle_attacknum >= player_attacknum:
            PlayerTurn_vs_Goyle()
#MultiAttack
def MultiAttack():
    global player_hp
    global goyle_hp
    try:
        player_turn=0
        goyle_turn=0
        goyle_attack = random.randint(1,20)
        if goyle_attack + 2>player_ac:
            if "piercing" in player_resistancies and "slashing" in player_resistancies:
                damage=((random.randint(1,6)+2))/2+((random.randint(1,6)+2)/2)
                player_hp=player_hp-damage
                print("Goyle lunges at ye, swinging his claws from the left side and reaching his mouth toward ye on the right! Ye have", player_hp, "HP left")
                if player_hp>0:
                    goyle_turn=goyle_turn+1
                    if goyle_turn>player_turn:
                        PlayerTurn_vs_Goyle()
                elif player_hp<1:
                    YouDied()
            elif "piercing" in player_resistancies or "slashing" in player_resistancies:
                damage=((random.randint(1,6)+2))/2+(random.randint(1,6)+2)
                player_hp=player_hp-damage
                print("Goyle lunges at ye, swinging his claws from the left side and reaching his mouth toward ye on the right! Ye have", player_hp, "HP left")
                if player_hp>0:
                    goyle_turn=goyle_turn+1
                    if goyle_turn>player_turn:
                        PlayerTurn_vs_Goyle()
                elif player_hp<1:
                    YouDied()
            else:
                damage=(random.randint(1,6)+2)+(random.randint(1,6)+2)
                player_hp=player_hp-damage
                print("Goyle lunges at ye, swinging his claws from the left side and reaching his mouth toward ye on the right! Ye have", player_hp, "HP left")
                if player_hp>0:
                    goyle_turn=goyle_turn+1
                    if goyle_turn>player_turn:
                        PlayerTurn_vs_Goyle()
                elif player_hp<1:
                    YouDied()
        elif goyle_attack + 2<=player_ac:
            damage = 0
            print("Goyle attempts to use both his claws and jaw in one mencaing attack, but he misses!")
            goyle_turn=goyle_turn+1
            if goyle_turn>player_turn:
                return PlayerTurn_vs_Goyle()
    except ValueError:
        print("Well that's not a valid option, me friend!")
        GoyleTurn()
        
#bite                  
def Bite():
    global player_hp
    global goyle_hp
    try:
        goyle_attack = random.randint(1,20)
        goyle_turn=0
        player_turn=0
        if goyle_attack + 2>player_ac:
            if "piercing" in player_resistancies:
                damage=((random.randint(1,6)+2))/2
                player_hp=player_hp-damage
                print("Goyle bites down into yer flesh! Ye have", player_hp, "HP left")
                if player_hp>0:
                    goyle_turn=goyle_turn+1
                    if goyle_turn>player_turn:
                        PlayerTurn_vs_Goyle()
                elif player_hp<1:
                    YouDied()
            else:
                damage=(random.randint(1,6)+2)
                player_hp=player_hp-damage
                print("Goyle bites down deep into yer flesh! Ye have", player_hp, "HP left")
                if player_hp>0:
                    goyle_turn=goyle_turn+1
                    if goyle_turn>player_turn:
                        PlayerTurn_vs_Goyle()
                elif player_hp<1:
                    YouDied()
        elif goyle_attack + 2<=player_ac:
            damage = 0
            print("Goyle clasps his jaw shut, but ye just barely dodge his gaping maw!")
            goyle_turn=goyle_turn+1
            if goyle_turn>player_turn:
                PlayerTurn_vs_Goyle()
    except ValueError:
        print("Well that's not a valid option, me friend!")
        GoyleTurn()
        
#claws
def Claws():
    global player_hp
    global goyle_hp
    try:
        goyle_attack = random.randint(1,20)
        goyle_turn=0
        player_turn=0
        if goyle_attack + 2>player_ac:
            if "slashing" in player_resistancies:
                damage=((random.randint(1,6)+2))/2
                player_hp=player_hp-damage
                print("Goyle swings his paw at ye, leaving three slash marks! Ye have", player_hp, "HP left")
                if player_hp>0:
                    goyle_turn=goyle_turn+1
                    if goyle_turn>player_turn:
                        PlayerTurn_vs_Goyle()
                elif player_hp<1:
                    YouDied()
            else:
                damage=(random.randint(1,6)+2)
                player_hp=player_hp-damage
                print("Goyle swings his paw at ye! That's gon' to leave a scar! Ye have", player_hp, "HP left")
                if player_hp>0:
                    goyle_turn=goyle_turn+1
                    if goyle_turn>player_turn:
                        PlayerTurn_vs_Goyle()
                elif player_hp<1:
                    YouDied()
        elif goyle_attack + 2<=player_ac:
            damage = 0
            print("Goyle brings down his paw, but ye sidestep quick enough to get out of the way!")
            goyle_turn=goyle_turn+1
            if goyle_turn>player_turn:
                return PlayerTurn_vs_Goyle()
    except ValueError:
        print("Well that's not a valid option, me friend!")
        GoyleTurn()

print("There is a gargoyle in the antechambre. It bares its teeth at ye and growls. It doesn't seem to be speaking any language ye recognize until it says three sentences, which seem to be very rehearsed: 'My name is Goyle, the defender of the lost realm. The treasure you seek beyond this path carries dangers beyond your reckoning. If you wish to proceed, then prepare to die!'.")
if player_num>goyle_num:    
    turn1=PlayerTurn_vs_Goyle()
if player_num==goyle_num:
    turn1=PlayerTurn_vs_Goyle()
if goyle_num>player_num:
    turn1=GoyleTurn()

while True:
    if turn1 == PlayerTurn_vs_Goyle:
        Player1_vs_Goyle
        if goyle_hp<1:
            print("Goyle has died!")
            break
        else:
            GoyleTurn()
            if player_hp<1:
                YouDied()
                break
    else:
        GoyleTurn()
        if player_hp<1:
            YouDied()
            break
        else:
            Player1_vs_Goyle
            if goyle_hp<1:
                print("Goyle has died!")
                break
# Out:
# There is a gargoyle in the antechambre. It bares its teeth at ye and growls. It doesn't seem to be speaking any language ye recognize until it says three sentences, which seem to be very rehearsed: 'My name is Goyle, the defender of the lost realm. The treasure you seek beyond this path carries dangers beyond your reckoning. If you wish to proceed, then prepare to die!'.
# That isn't something ye can do now ya see
# Ye hit Goyle! Goyle has 42 HP left!
# Well that's not somethin' ye can do!
